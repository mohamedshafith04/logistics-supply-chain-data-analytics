# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
customers=pd.read_csv("customers.csv")
drivers=pd.read_csv("drivers.csv")
trucks=pd.read_csv("trucks.csv")
trailers=pd.read_csv("trailers.csv")
facilities=pd.read_csv("facilities.csv")
routes=pd.read_csv("routes.csv")
loads=pd.read_csv("loads.csv")
trips=pd.read_csv("trips.csv")
fuel_purchases=pd.read_csv("fuel_purchases.csv")
maintenance_records=pd.read_csv("maintenance_records.csv")
delivery_events=pd.read_csv("delivery_events.csv")
safety_incidents=pd.read_csv("safety_incidents.csv")
driver_monthly_metrics=pd.read_csv("driver_monthly_metrics.csv")
truck_utilization_metrics=pd.read_csv("truck_utilization_metrics.csv")

# %%
customers
# Out:
#     customer_id          customer_name customer_type  credit_terms_days  \
# 0     CUST00001        Metro Wholesale     Dedicated                 60
# 1     CUST00002        National Retail      Contract                 30
# 2     CUST00003         XYZ Industries      Contract                 30
# 3     CUST00004          American Corp      Contract                 15
# 4     CUST00005  American Distribution          Spot                 45
# ..          ...                    ...           ...                ...
# 195   CUST00196          XYZ Logistics          Spot                 60
# 196   CUST00197               ABC Corp      Contract                 15
# 197   CUST00198        Elite Wholesale     Dedicated                 60
# 198   CUST00199            First Group      Contract                 15
# 199   CUST00200              XYZ Foods     Dedicated                 45
#
#     primary_freight_type account_status contract_start_date  \
# ...

# %%
#data exploration (customers)


print(f"head:\n{customers.head(5)}")                                
print(f"tail:\n{customers.tail(5)}")                               
print("info:")                                            
print(customers.info())
print(f"describe:\n{customers.describe()}")                         
print(f"shape:{customers.shape}")                                   
print(f"column:\n{customers.columns}")   
print(f"size:\n{customers.size}")
# Out:
# head:
#   customer_id          customer_name customer_type  credit_terms_days  \
# 0   CUST00001        Metro Wholesale     Dedicated                 60
# 1   CUST00002        National Retail      Contract                 30
# 2   CUST00003         XYZ Industries      Contract                 30
# 3   CUST00004          American Corp      Contract                 15
# 4   CUST00005  American Distribution          Spot                 45
#
#   primary_freight_type account_status contract_start_date  \
# 0              General       Inactive          2020-02-20
# 1               Retail         Active          2021-06-02
# 2       Consumer Goods         Active          2020-09-04
# 3        Food/Beverage         Active          2020-11-29
# 4       Consumer Goods         Active          2020-02-04
#
#    annual_revenue_potential
# 0                    985117
# 1                   4936566
# 2                   3102814
# 3                   3948027
# 4                   3682564
# tail:
# ...

# %%
# Data Exploration (Drivers)

print(f"Head:\n{drivers.head(5)}")
print(f"Tail:\n{drivers.tail(5)}")
print("Info:")
drivers.info()
print(f"Describe:\n{drivers.describe()}")
print(f"Shape: {drivers.shape}")
print(f"Columns:\n{drivers.columns}")
print(f"Size: {drivers.size}")
# Out:
# Head:
#   driver_id first_name  last_name   hire_date termination_date license_number  \
# 0  DRV00001   Jennifer  Hernandez  2014-10-31              NaN    DL673510887
# 1  DRV00002    William     Martin  2020-10-02              NaN    DL128955006
# 2  DRV00003    Charles  Hernandez  2021-09-21              NaN    DL523076025
# 3  DRV00004    Barbara      Brown  2013-09-08              NaN    DL735540030
# 4  DRV00005       Mary   Martinez  2018-12-02              NaN    DL706011277
#
#   license_state date_of_birth   home_terminal employment_status cdl_class  \
# 0            WA    1973-11-07          Denver            Active         A
# 1            GA    1976-11-03        Columbus            Active         A
# 2            NC    1970-04-06  Salt Lake City            Active         A
# 3            WA    1995-02-06          Denver            Active         A
# 4            AZ    1960-07-15         Chicago            Active         A
#
#    years_experience
# 0                 3
# ...

# %%
drivers.head()
# Out:
#   driver_id first_name  last_name   hire_date termination_date license_number  \
# 0  DRV00001   Jennifer  Hernandez  2014-10-31              NaN    DL673510887
# 1  DRV00002    William     Martin  2020-10-02              NaN    DL128955006
# 2  DRV00003    Charles  Hernandez  2021-09-21              NaN    DL523076025
# 3  DRV00004    Barbara      Brown  2013-09-08              NaN    DL735540030
# 4  DRV00005       Mary   Martinez  2018-12-02              NaN    DL706011277
#
#   license_state date_of_birth   home_terminal employment_status cdl_class  \
# 0            WA    1973-11-07          Denver            Active         A
# 1            GA    1976-11-03        Columbus            Active         A
# 2            NC    1970-04-06  Salt Lake City            Active         A
# 3            WA    1995-02-06          Denver            Active         A
# 4            AZ    1960-07-15         Chicago            Active         A
#
#    years_experience
# 0                 3
# ...

# %%
# Data Exploration (Trucks)

print(f"Head:\n{trucks.head(5)}")
print(f"Tail:\n{trucks.tail(5)}")
print("Info:")
trucks.info()
print(f"Describe:\n{trucks.describe()}")
print(f"Shape: {trucks.shape}")
print(f"Columns:\n{trucks.columns}")
print(f"Size: {trucks.size}")
# Out:
# Head:
#    truck_id  unit_number          make  model_year                 vin  \
# 0  TRK00001         3463     Peterbilt        2016  1VV205190335317039
# 1  TRK00002         6461      Kenworth        2015  1NV753749606229960
# 2  TRK00003         2335     Peterbilt        2018  1NT803101860493229
# 3  TRK00004         3317  Freightliner        2015  1VV131945381692351
# 4  TRK00005         6731  Freightliner        2016  1FT822215709701985
#
#   acquisition_date  acquisition_mileage fuel_type  tank_capacity_gallons  \
# 0       2017-04-27                18814    Diesel                    200
# 1       2018-10-04                26795    Diesel                    150
# 2       2020-09-17                11795    Diesel                    150
# 3       2017-06-17                 8875    Diesel                    200
# 4       2021-10-08                42042    Diesel                    250
#
#         status   home_terminal
# 0       Active           Omaha
# ...

# %%
# Data Exploration (Trailers)

print(f"Head:\n{trailers.head(5)}")
print(f"Tail:\n{trailers.tail(5)}")
print("Info:")
trailers.info()
print(f"Describe:\n{trailers.describe()}")
print(f"Shape: {trailers.shape}")
print(f"Columns:\n{trailers.columns}")
print(f"Size: {trailers.size}")
# Out:
# Head:
#   trailer_id  trailer_number  trailer_type  length_feet  model_year  \
# 0   TRL00001            4290  Refrigerated           53        2016
# 1   TRL00002            8848       Dry Van           53        2018
# 2   TRL00003            6147       Dry Van           53        2022
# 3   TRL00004            3910       Dry Van           53        2024
# 4   TRL00005            7524       Dry Van           53        2016
#
#                   vin acquisition_date  status current_location
# 0  1AV889081755621178       2018-05-11  Active      Kansas City
# 1  1BU942062588832828       2018-11-24  Active      Kansas City
# 2  1AV669057807416326       2019-01-28  Active        Milwaukee
# 3  1AV544000060905105       2018-08-27  Active         New York
# 4  1AV170126369813275       2019-11-22  Active        Las Vegas
# Tail:
#     trailer_id  trailer_number  trailer_type  length_feet  model_year  \
# 175   TRL00176            9109  Refrigerated           53        2015
# ...

# %%
# Data Exploration (Facilities)

print(f"Head:\n{facilities.head(5)}")
print(f"Tail:\n{facilities.tail(5)}")
print("Info:")
facilities.info()
print(f"Describe:\n{facilities.describe()}")
print(f"Shape: {facilities.shape}")
print(f"Columns:\n{facilities.columns}")
print(f"Size: {facilities.size}")
# Out:
# Head:
#   facility_id                  facility_name        facility_type  \
# 0    FAC00001    Houston Distribution Center           Cross-Dock
# 1    FAC00002                Kansas City Hub           Cross-Dock
# 2    FAC00003  Charlotte Distribution Center  Distribution Center
# 3    FAC00004    Chicago Distribution Center  Distribution Center
# 4    FAC00005               Indianapolis Hub  Distribution Center
#
#            city state  latitude  longitude  dock_doors operating_hours
# 0       Houston    TX   29.7604   -95.3698         125            24/7
# 1   Kansas City    MO   39.0997   -94.5786          33         7AM-7PM
# 2     Charlotte    NC   35.2271   -80.8431         138            24/7
# 3       Chicago    IL   41.8781   -87.6298          38         8AM-5PM
# 4  Indianapolis    IN   39.7684   -86.1581          56         8AM-5PM
# Tail:
#    facility_id                    facility_name        facility_type  \
# ...

# %%
# Data Exploration (Routes)

print(f"Head:\n{routes.head(5)}")
print(f"Tail:\n{routes.tail(5)}")
print("Info:")
routes.info()
print(f"Describe:\n{routes.describe()}")
print(f"Shape: {routes.shape}")
print(f"Columns:\n{routes.columns}")
print(f"Size: {routes.size}")
# Out:
# Head:
#    route_id origin_city origin_state destination_city destination_state  \
# 0  RTE00001     Atlanta           GA          Chicago                IL
# 1  RTE00002     Atlanta           GA            Miami                FL
# 2  RTE00003     Chicago           IL      Los Angeles                CA
# 3  RTE00004     Chicago           IL         Portland                OR
# 4  RTE00005     Chicago           IL        Las Vegas                NV
#
#    typical_distance_miles  base_rate_per_mile  fuel_surcharge_rate  \
# 0                     677                1.70                 0.19
# 1                     697                2.08                 0.22
# 2                    2003                2.55                 0.29
# 3                    2017                1.84                 0.19
# 4                    1749                2.41                 0.26
#
#    typical_transit_days
# 0                     1
# 1                     1
# 2                     3
# ...

# %%
# Data Exploration (Loads)

print(f"Head:\n{loads.head(5)}")
print(f"Tail:\n{loads.tail(5)}")
print("Info:")
loads.info()
print(f"Describe:\n{loads.describe()}")
print(f"Shape: {loads.shape}")
print(f"Columns:\n{loads.columns}")
print(f"Size: {loads.size}")
# Out:
# Head:
#         load_id customer_id  route_id   load_date     load_type  weight_lbs  \
# 0  LOAD00000001   CUST00183  RTE00019  2022-01-01       Dry Van       19178
# 1  LOAD00000002   CUST00076  RTE00058  2022-01-01       Dry Van       27761
# 2  LOAD00000003   CUST00027  RTE00048  2022-01-01  Refrigerated       35594
# 3  LOAD00000004   CUST00088  RTE00013  2022-01-01  Refrigerated       33274
# 4  LOAD00000005   CUST00185  RTE00020  2022-01-01       Dry Van       40257
#
#    pieces  revenue  fuel_surcharge  accessorial_charges load_status  \
# 0      13  3045.23          406.72                  100   Completed
# 1      22  1224.48           98.61                    0   Completed
# 2      16  7171.12          792.88                    0   Completed
# 3      10  1308.20          141.33                   50   Completed
# 4      10  3317.18          738.48                    0   Completed
#
#   booking_type
# 0         Spot
# 1    Dedicated
# 2         Spot
# 3         Spot
# ...

# %%
# Data Exploration (Trips)

print(f"Head:\n{trips.head(5)}")
print(f"Tail:\n{trips.tail(5)}")
print("Info:")
trips.info()
print(f"Describe:\n{trips.describe()}")
print(f"Shape: {trips.shape}")
print(f"Columns:\n{trips.columns}")
print(f"Size: {trips.size}")
# Out:
# Head:
#         trip_id       load_id driver_id  truck_id trailer_id dispatch_date  \
# 0  TRIP00000001  LOAD00000001  DRV00117  TRK00035   TRL00167    2022-01-01
# 1  TRIP00000002  LOAD00000002  DRV00141  TRK00108   TRL00082    2022-01-01
# 2  TRIP00000003  LOAD00000003  DRV00032  TRK00031   TRL00138    2022-01-01
# 3  TRIP00000004  LOAD00000004  DRV00083  TRK00105   TRL00018    2022-01-01
# 4  TRIP00000005  LOAD00000005  DRV00044  TRK00076   TRL00054    2022-01-01
#
#    actual_distance_miles  actual_duration_hours  fuel_litres  average_mpl  \
# 0                   1314                   26.2        183.8         7.15
# 1                    515                    8.6         93.6         5.50
# 2                   2509                   45.0        339.1         7.40
# 3                    717                   11.1        110.3         6.50
# 4                   2243                   35.0        328.9         6.82
#
#    idle_time_hours trip_status
# ...

# %%
# Data Exploration (Delivery Events)

print(f"Head:\n{delivery_events.head(5)}")
print(f"Tail:\n{delivery_events.tail(5)}")
print("Info:")
delivery_events.info()
print(f"Describe:\n{delivery_events.describe()}")
print(f"Shape: {delivery_events.shape}")
print(f"Columns:\n{delivery_events.columns}")
print(f"Size: {delivery_events.size}")
# Out:
# Head:
#       event_id       load_id       trip_id event_type facility_id  \
# 0  EVT00000001  LOAD00000001  TRIP00000001     Pickup    FAC00034
# 1  EVT00000002  LOAD00000001  TRIP00000001   Delivery    FAC00046
# 2  EVT00000003  LOAD00000002  TRIP00000002     Pickup    FAC00015
# 3  EVT00000004  LOAD00000002  TRIP00000002   Delivery    FAC00050
# 4  EVT00000005  LOAD00000003  TRIP00000003     Pickup    FAC00001
#
#            scheduled_datetime             actual_datetime  detention_minutes  \
# 0  2022-01-01 18:00:00.000000  2022-01-01 20:58:55.918185                  0
# 1  2022-01-02 23:10:55.918185  2022-01-02 21:30:22.142060                230
# 2  2022-01-01 18:00:00.000000  2022-01-01 17:37:26.608430                 62
# 3  2022-01-02 02:13:26.608430  2022-01-02 05:55:46.238257                 67
# 4  2022-01-01 08:00:00.000000  2022-01-01 07:28:02.169634                 83
#
#    on_time_flag location_city location_state
# 0         False       Houston             TX
# ...

# %%
# Data Exploration (Fuel Purchases)

print(f"Head:\n{fuel_purchases.head(5)}")
print(f"Tail:\n{fuel_purchases.tail(5)}")
print("Info:")
fuel_purchases.info()
print(f"Describe:\n{fuel_purchases.describe()}")
print(f"Shape: {fuel_purchases.shape}")
print(f"Columns:\n{fuel_purchases.columns}")
print(f"Size: {fuel_purchases.size}")
# Out:
# Head:
#   fuel_purchase_id       trip_id  truck_id driver_id        purchase_date  \
# 0     FUEL00000001  TRIP00051284  TRK00045  DRV00102  2023-10-22 05:00:00
# 1     FUEL00000002  TRIP00073723  TRK00013       NaN  2024-08-04 08:00:00
# 2     FUEL00000003  TRIP00018286  TRK00024  DRV00142  2022-08-23 13:00:00
# 3     FUEL00000004  TRIP00008465  TRK00018  DRV00047  2022-04-20 00:00:00
# 4     FUEL00000005  TRIP00069700  TRK00054       NaN  2024-06-13 09:00:00
#
#   location_city location_state  gallons  price_per_gallon  total_cost  \
# 0      Columbus             MN    131.6             3.399      447.31
# 1      New York             AZ    139.9             3.180      444.88
# 2       Seattle             NE    189.3             3.804      720.10
# 3       Memphis             NY    130.7             3.579      467.78
# 4      Columbus             AZ    185.3             3.422      634.10
#
#   fuel_card_number
# 0         FC567161
# 1         FC717910
# 2         FC912816
# ...

# %%
# Data Exploration (Maintenance Records)

print(f"Head:\n{maintenance_records.head(5)}")
print(f"Tail:\n{maintenance_records.tail(5)}")
print("Info:")
maintenance_records.info()
print(f"Describe:\n{maintenance_records.describe()}")
print(f"Shape: {maintenance_records.shape}")
print(f"Columns:\n{maintenance_records.columns}")
print(f"Size: {maintenance_records.size}")
# Out:
# Head:
#   maintenance_id  truck_id maintenance_date maintenance_type  \
# 0  MAINT00000001  TRK00085       2022-01-01       Inspection
# 1  MAINT00000002  TRK00041       2022-01-01             Tire
# 2  MAINT00000003  TRK00090       2022-01-01       Preventive
# 3  MAINT00000004  TRK00056       2022-01-02       Inspection
# 4  MAINT00000005  TRK00029       2022-01-02           Repair
#
#    odometer_reading  labor_hours  labor_cost  parts_cost  total_cost  \
# 0            400255          7.8      781.42       10.41      791.83
# 1            268041          0.9       80.91     3207.16     3288.07
# 2            698915          7.2      733.18     1570.57     2303.75
# 3            416522          2.8      298.80       67.48      366.28
# 4            179968          4.6      409.08      982.59     1391.67
#
#   facility_location  downtime_hours   service_description
# 0       Kansas City            22.2  Emergency Inspection
# ...

# %%
# Data Exploration (Driver Monthly Metrics)

print(f"Head:\n{driver_monthly_metrics.head(5)}")
print(f"Tail:\n{driver_monthly_metrics.tail(5)}")
print("Info:")
driver_monthly_metrics.info()
print(f"Describe:\n{driver_monthly_metrics.describe()}")
print(f"Shape: {driver_monthly_metrics.shape}")
print(f"Columns:\n{driver_monthly_metrics.columns}")
print(f"Size: {driver_monthly_metrics.size}")
# Out:
# Head:
#   driver_id       month  trips_completed  total_miles  total_revenue  \
# 0  DRV00001  2022-01-01               26        36620       79141.59
# 1  DRV00001  2022-02-01                9        13515       27133.87
# 2  DRV00001  2022-03-01               20        30361       62399.62
# 3  DRV00001  2022-04-01               19        28127       68161.13
# 4  DRV00001  2022-05-01               14        16071       36256.82
#
#    average_mpg  total_fuel_gallons  on_time_delivery_rate  average_idle_hours
# 0         6.61              5574.7                  0.385                 8.2
# 1         6.69              2095.1                  0.333                 6.8
# 2         6.36              4792.2                  0.550                 7.5
# 3         6.61              4251.4                  0.474                 8.4
# 4         6.35              2573.1                  0.214                 6.8
# Tail:
# ...

# %%
# Data Exploration (Truck Utilization Metrics)

print(f"Head:\n{truck_utilization_metrics.head(5)}")
print(f"Tail:\n{truck_utilization_metrics.tail(5)}")
print("Info:")
truck_utilization_metrics.info()
print(f"Describe:\n{truck_utilization_metrics.describe()}")
print(f"Shape: {truck_utilization_metrics.shape}")
print(f"Columns:\n{truck_utilization_metrics.columns}")
print(f"Size: {truck_utilization_metrics.size}")
# Out:
# Head:
#    truck_id       month  trips_completed  total_miles  total_revenue  \
# 0  TRK00001  2022-01-01               22        39269       84792.02
# 1  TRK00001  2022-02-01               27        40787       88809.05
# 2  TRK00001  2022-03-01               34        57422      120453.71
# 3  TRK00001  2022-04-01               20        34428       73531.28
# 4  TRK00001  2022-05-01               16        20851       40791.53
#
#    average_mpg  maintenance_events  maintenance_cost  downtime_hours  \
# 0         6.78                   2           4380.98            63.1
# 1         6.23                   0              0.00             0.0
# 2         6.49                   0              0.00             0.0
# 3         6.50                   2           3548.15            71.8
# 4         6.38                   1           1969.42            43.9
#
#    utilization_rate
# 0             0.710
# 1             0.964
# 2             1.097
# 3             0.667
# ...

# %%
# Data Exploration (Safety Incidents)

print(f"Head:\n{safety_incidents.head(5)}")
print(f"Tail:\n{safety_incidents.tail(5)}")
print("Info:")
safety_incidents.info()
print(f"Describe:\n{safety_incidents.describe()}")
print(f"Shape: {safety_incidents.shape}")
print(f"Columns:\n{safety_incidents.columns}")
print(f"Size: {safety_incidents.size}")
# Out:
# Head:
#    incident_id       trip_id  truck_id driver_id        incident_date  \
# 0  INC00000001  TRIP00036079  TRK00006  DRV00006  2023-04-09 14:00:00
# 1  INC00000002  TRIP00032462  TRK00084  DRV00006  2023-02-19 11:00:00
# 2  INC00000003  TRIP00067583  TRK00106  DRV00119  2024-05-20 01:00:00
# 3  INC00000004  TRIP00049128  TRK00085  DRV00134  2023-09-26 03:00:00
# 4  INC00000005  TRIP00062884  TRK00014  DRV00133  2024-03-20 14:00:00
#
#         incident_type location_city location_state  at_fault_flag  \
# 0    Moving Violation      Columbus             PA           True
# 1    Moving Violation      Columbus             NC          False
# 2  Customer Complaint       Seattle             OK           True
# 3    Equipment Damage   Kansas City             TN           True
# 4       DOT Violation     Las Vegas             IN          False
#
#    injury_flag  vehicle_damage_cost  cargo_damage_cost  claim_amount  \
# ...

# %%
# data cleaning(customers)

print(f"isna:\n{customers.isna().sum()}")
print(f"duplicated:\n{customers.duplicated().sum()}")
print(f"dtypes:\n{customers.dtypes}")
customers["contract_start_date"] = pd.to_datetime(customers["contract_start_date"])
print(customers.dtypes)
# Out:
# isna:
# customer_id                 0
# customer_name               0
# customer_type               0
# credit_terms_days           0
# primary_freight_type        0
# account_status              0
# contract_start_date         0
# annual_revenue_potential    0
# dtype: int64
# duplicated:
# 0
# dtypes:
# customer_id                 object
# customer_name               object
# customer_type               object
# credit_terms_days            int64
# primary_freight_type        object
# account_status              object
# contract_start_date         object
# annual_revenue_potential     int64
# dtype: object
# customer_id                         object
# customer_name                       object
# customer_type                       object
# credit_terms_days                    int64
# primary_freight_type                object
# account_status                      object
# contract_start_date         datetime64[ns]
# annual_revenue_potential             int64
# dtype: object

# %%
drivers.head(8)
# Out:
#   driver_id first_name  last_name   hire_date termination_date license_number  \
# 0  DRV00001   Jennifer  Hernandez  2014-10-31              NaN    DL673510887
# 1  DRV00002    William     Martin  2020-10-02              NaN    DL128955006
# 2  DRV00003    Charles  Hernandez  2021-09-21              NaN    DL523076025
# 3  DRV00004    Barbara      Brown  2013-09-08              NaN    DL735540030
# 4  DRV00005       Mary   Martinez  2018-12-02              NaN    DL706011277
# 5  DRV00006     Robert     Taylor  2019-04-04              NaN    DL811890569
# 6  DRV00007      James   Martinez  2019-07-02       2021-05-17    DL129100607
# 7  DRV00008    Barbara     Wilson  2020-06-09       2021-01-23    DL190137896
#
#   license_state date_of_birth   home_terminal employment_status cdl_class  \
# 0            WA    1973-11-07          Denver            Active         A
# 1            GA    1976-11-03        Columbus            Active         A
# ...

# %%
# Data Cleaning - Drivers

print(f"isna:\n{drivers.isna().sum()}")
print(f"missing termination_date:\n{drivers[drivers["termination_date"].isna()]}")
print(f"employee_status:\n{drivers["employment_status"].head(8)}")
print(f"employment_status:\n{drivers["employment_status"].unique()}")
print(f"duplicated:\n{drivers.duplicated().sum()}")
print(f"dtypes:\n{drivers.dtypes}")
# Out:
# isna:
# driver_id              0
# first_name             0
# last_name              0
# hire_date              0
# termination_date     124
# license_number         0
# license_state          0
# date_of_birth          0
# home_terminal          0
# employment_status      0
# cdl_class              0
# years_experience       0
# dtype: int64
# missing termination_date:
#     driver_id first_name  last_name   hire_date termination_date  \
# 0    DRV00001   Jennifer  Hernandez  2014-10-31              NaN
# 1    DRV00002    William     Martin  2020-10-02              NaN
# 2    DRV00003    Charles  Hernandez  2021-09-21              NaN
# 3    DRV00004    Barbara      Brown  2013-09-08              NaN
# 4    DRV00005       Mary   Martinez  2018-12-02              NaN
# ..        ...        ...        ...         ...              ...
# 145  DRV00146    Jessica   Gonzalez  2019-01-13              NaN
# 146  DRV00147    Richard     Garcia  2020-06-09              NaN
# ...

# %%
trucks
# Out:
#      truck_id  unit_number           make  model_year                 vin  \
# 0    TRK00001         3463      Peterbilt        2016  1VV205190335317039
# 1    TRK00002         6461       Kenworth        2015  1NV753749606229960
# 2    TRK00003         2335      Peterbilt        2018  1NT803101860493229
# 3    TRK00004         3317   Freightliner        2015  1VV131945381692351
# 4    TRK00005         6731   Freightliner        2016  1FT822215709701985
# ..        ...          ...            ...         ...                 ...
# 115  TRK00116         3449  International        2019  1MV446968103715126
# 116  TRK00117         9991      Peterbilt        2015  1FU939700479057712
# 117  TRK00118         9647   Freightliner        2015  1NV150990165397549
# 118  TRK00119         7934           Mack        2015  1MU171789091515507
# 119  TRK00120         2821          Volvo        2017  1FT135731860465802
#
#     acquisition_date  acquisition_mileage fuel_type  tank_capacity_gallons  \
# ...

# %%
# Data cleaning (trucks)

print(f"isna:\n{trucks.isna().sum()}")
print(f"duplicated:\n{trucks.duplicated().sum()}")
print(f"dtypes:\n{trucks.dtypes}")
print(f"make:\n{trucks['make'].unique()}")
print(f"fuel_type:\n{trucks['fuel_type'].unique()}")
print(f"status:\n{trucks['status'].unique()}")
# Out:
# isna:
# truck_id                 0
# unit_number              0
# make                     0
# model_year               0
# vin                      0
# acquisition_date         0
# acquisition_mileage      0
# fuel_type                0
# tank_capacity_gallons    0
# status                   0
# home_terminal            0
# dtype: int64
# duplicated:
# 0
# dtypes:
# truck_id                 object
# unit_number               int64
# make                     object
# model_year                int64
# vin                      object
# acquisition_date         object
# acquisition_mileage       int64
# fuel_type                object
# tank_capacity_gallons     int64
# status                   object
# home_terminal            object
# dtype: object
# make:
# ['Peterbilt' 'Kenworth' 'Freightliner' 'Volvo' 'Mack' 'International']
# fuel_type:
# ['Diesel']
# status:
# ['Active' 'Maintenance' 'Inactive']

# %%
trailers
# Out:
#     trailer_id  trailer_number  trailer_type  length_feet  model_year  \
# 0     TRL00001            4290  Refrigerated           53        2016
# 1     TRL00002            8848       Dry Van           53        2018
# 2     TRL00003            6147       Dry Van           53        2022
# 3     TRL00004            3910       Dry Van           53        2024
# 4     TRL00005            7524       Dry Van           53        2016
# ..         ...             ...           ...          ...         ...
# 175   TRL00176            9109  Refrigerated           53        2015
# 176   TRL00177            7703       Dry Van           53        2017
# 177   TRL00178            9056       Dry Van           53        2019
# 178   TRL00179            7809  Refrigerated           53        2016
# 179   TRL00180            8272  Refrigerated           53        2015
#
#                     vin acquisition_date  status current_location
# ...

# %%
#Data cleaning (trailers)
print(f"isna:\n{trailers.isna().sum()}")
print(f"duplicated:\n{trailers.duplicated().sum()}")
print(f"dtypes:\n{trailers.dtypes}")
print(f"trailer_type:\n{trailers['trailer_type'].unique()}")
print(f"status:\n{trailers['status'].unique()}")
trailers["acquisition_date"] = pd.to_datetime(trailers["acquisition_date"])
# Out:
# isna:
# trailer_id          0
# trailer_number      0
# trailer_type        0
# length_feet         0
# model_year          0
# vin                 0
# acquisition_date    0
# status              0
# current_location    0
# dtype: int64
# duplicated:
# 0
# dtypes:
# trailer_id          object
# trailer_number       int64
# trailer_type        object
# length_feet          int64
# model_year           int64
# vin                 object
# acquisition_date    object
# status              object
# current_location    object
# dtype: object
# trailer_type:
# ['Refrigerated' 'Dry Van']
# status:
# ['Active']

# %%
facilities
# Out:
#    facility_id                     facility_name        facility_type  \
# 0     FAC00001       Houston Distribution Center           Cross-Dock
# 1     FAC00002                   Kansas City Hub           Cross-Dock
# 2     FAC00003     Charlotte Distribution Center  Distribution Center
# 3     FAC00004       Chicago Distribution Center  Distribution Center
# 4     FAC00005                  Indianapolis Hub  Distribution Center
# 5     FAC00006                 Atlanta Warehouse  Distribution Center
# 6     FAC00007                 Detroit Warehouse             Terminal
# 7     FAC00008                  Philadelphia Hub           Cross-Dock
# 8     FAC00009     Nashville Distribution Center             Terminal
# 9     FAC00010  Indianapolis Distribution Center            Warehouse
# 10    FAC00011     Nashville Distribution Center           Cross-Dock
# 11    FAC00012       Atlanta Distribution Center  Distribution Center
# ...

# %%
# Data cleaning (facilities)

print(f"isna:\n{facilities.isna().sum()}")
print(f"duplicated:\n{facilities.duplicated().sum()}")
print(f"dtypes:\n{facilities.dtypes}")
print(f"facility_type:\n{facilities['facility_type'].unique()}")
print(f"city:\n{facilities['city'].unique()}")
# Out:
# isna:
# facility_id        0
# facility_name      0
# facility_type      0
# city               0
# state              0
# latitude           0
# longitude          0
# dock_doors         0
# operating_hours    0
# dtype: int64
# duplicated:
# 0
# dtypes:
# facility_id         object
# facility_name       object
# facility_type       object
# city                object
# state               object
# latitude           float64
# longitude          float64
# dock_doors           int64
# operating_hours     object
# dtype: object
# facility_type:
# ['Cross-Dock' 'Distribution Center' 'Terminal' 'Warehouse']
# city:
# ['Houston' 'Kansas City' 'Charlotte' 'Chicago' 'Indianapolis' 'Atlanta'
#  'Detroit' 'Philadelphia' 'Nashville' 'Phoenix' 'Omaha' 'Dallas'
#  'Las Vegas' 'New York' 'Portland' 'Denver' 'Oklahoma City' 'Miami'
#  'Los Angeles' 'Salt Lake City' 'Milwaukee']

# %%
routes
# Out:
#     route_id   origin_city origin_state destination_city destination_state  \
# 0   RTE00001       Atlanta           GA          Chicago                IL
# 1   RTE00002       Atlanta           GA            Miami                FL
# 2   RTE00003       Chicago           IL      Los Angeles                CA
# 3   RTE00004       Chicago           IL         Portland                OR
# 4   RTE00005       Chicago           IL        Las Vegas                NV
# 5   RTE00006       Chicago           IL        Charlotte                NC
# 6   RTE00007        Dallas           TX         New York                NY
# 7   RTE00008        Dallas           TX           Denver                CO
# 8   RTE00009        Dallas           TX     Indianapolis                IN
# 9   RTE00010      New York           NY     Philadelphia                PA
# 10  RTE00011      New York           NY         Columbus                OH
# ...

# %%
# Data cleaning (routes)

print(f"isna:\n{routes.isna().sum()}")
print(f"duplicated:\n{routes.duplicated().sum()}")
print(f"dtypes:\n{routes.dtypes}")
print(f"origin_city:\n{routes['origin_city'].unique()}")
print(f"destination_city:\n{routes['destination_city'].unique()}")
# Out:
# isna:
# route_id                  0
# origin_city               0
# origin_state              0
# destination_city          0
# destination_state         0
# typical_distance_miles    0
# base_rate_per_mile        0
# fuel_surcharge_rate       0
# typical_transit_days      0
# dtype: int64
# duplicated:
# 0
# dtypes:
# route_id                   object
# origin_city                object
# origin_state               object
# destination_city           object
# destination_state          object
# typical_distance_miles      int64
# base_rate_per_mile        float64
# fuel_surcharge_rate       float64
# typical_transit_days        int64
# dtype: object
# origin_city:
# ['Atlanta' 'Chicago' 'Dallas' 'New York' 'Phoenix' 'Philadelphia'
#  'Houston' 'Miami' 'Detroit' 'Seattle' 'Denver' 'Portland' 'Las Vegas'
#  'Minneapolis' 'Charlotte' 'Columbus' 'Memphis' 'Kansas City']
# destination_city:
# ['Chicago' 'Miami' 'Los Angeles' 'Portland' 'Las Vegas' 'Charlotte'
# ...

# %%
loads
# Out:
#             load_id customer_id  route_id   load_date     load_type  \
# 0      LOAD00000001   CUST00183  RTE00019  2022-01-01       Dry Van
# 1      LOAD00000002   CUST00076  RTE00058  2022-01-01       Dry Van
# 2      LOAD00000003   CUST00027  RTE00048  2022-01-01  Refrigerated
# 3      LOAD00000004   CUST00088  RTE00013  2022-01-01  Refrigerated
# 4      LOAD00000005   CUST00185  RTE00020  2022-01-01       Dry Van
# ...             ...         ...       ...         ...           ...
# 85405  LOAD00085406   CUST00016  RTE00039  2024-12-31  Refrigerated
# 85406  LOAD00085407   CUST00179  RTE00008  2024-12-31       Dry Van
# 85407  LOAD00085408   CUST00136  RTE00056  2024-12-31  Refrigerated
# 85408  LOAD00085409   CUST00012  RTE00016  2024-12-31  Refrigerated
# 85409  LOAD00085410   CUST00169  RTE00007  2024-12-31       Dry Van
#
#        weight_lbs  pieces  revenue  fuel_surcharge  accessorial_charges  \
# 0           19178      13  3045.23          406.72                  100
# ...

# %%
# Data cleaning (loads)

print(f"isna:\n{loads.isna().sum()}")
print(f"duplicated:\n{loads.duplicated().sum()}")
print(f"dtypes:\n{loads.dtypes}")
print(f"load_type:\n{loads['load_type'].unique()}")
print(f"load_status:\n{loads['load_status'].unique()}")
print(f"booking_type:\n{loads['booking_type'].unique()}")
loads["load_date"] = pd.to_datetime(loads["load_date"])
# Out:
# isna:
# load_id                0
# customer_id            0
# route_id               0
# load_date              0
# load_type              0
# weight_lbs             0
# pieces                 0
# revenue                0
# fuel_surcharge         0
# accessorial_charges    0
# load_status            0
# booking_type           0
# dtype: int64
# duplicated:
# 0
# dtypes:
# load_id                 object
# customer_id             object
# route_id                object
# load_date               object
# load_type               object
# weight_lbs               int64
# pieces                   int64
# revenue                float64
# fuel_surcharge         float64
# accessorial_charges      int64
# load_status             object
# booking_type            object
# dtype: object
# load_type:
# ['Dry Van' 'Refrigerated']
# load_status:
# ['Completed']
# booking_type:
# ['Spot' 'Dedicated' 'Contract']

# %%
trips
# Out:
#             trip_id       load_id driver_id  truck_id trailer_id  \
# 0      TRIP00000001  LOAD00000001  DRV00117  TRK00035   TRL00167
# 1      TRIP00000002  LOAD00000002  DRV00141  TRK00108   TRL00082
# 2      TRIP00000003  LOAD00000003  DRV00032  TRK00031   TRL00138
# 3      TRIP00000004  LOAD00000004  DRV00083  TRK00105   TRL00018
# 4      TRIP00000005  LOAD00000005  DRV00044  TRK00076   TRL00054
# ...             ...           ...       ...       ...        ...
# 85405  TRIP00085406  LOAD00085406  DRV00005  TRK00029   TRL00058
# 85406  TRIP00085407  LOAD00085407  DRV00091  TRK00080   TRL00092
# 85407  TRIP00085408  LOAD00085408  DRV00011  TRK00051   TRL00083
# 85408  TRIP00085409  LOAD00085409  DRV00094  TRK00073   TRL00137
# 85409  TRIP00085410  LOAD00085410  DRV00049  TRK00099   TRL00033
#
#       dispatch_date  actual_distance_miles  actual_duration_hours  \
# 0        2022-01-01                   1314                   26.2
# ...

# %%
# Data cleaning (trips)

print(f"isna:\n{trips.isna().sum()}")
print(f"duplicated:\n{trips.duplicated().sum()}")
print(f"dtypes:\n{trips.dtypes}")
print(trips[trips["driver_id"].isna()])
print(trips[trips["truck_id"].isna()])
print(trips[trips["trailer_id"].isna()])
trips["driver_id"] = trips["driver_id"].fillna("Unknown")
trips["truck_id"] = trips["truck_id"].fillna("Unknown")
trips["trailer_id"] = trips["trailer_id"].fillna("Unknown")                       
print(trips.isna().sum())
# Out:
# isna:
# trip_id                     0
# load_id                     0
# driver_id                1714
# truck_id                 1672
# trailer_id               1680
# dispatch_date               0
# actual_distance_miles       0
# actual_duration_hours       0
# fuel_litres                 0
# average_mpl                 0
# idle_time_hours             0
# trip_status                 0
# dtype: int64
# duplicated:
# 0
# dtypes:
# trip_id                   object
# load_id                   object
# driver_id                 object
# truck_id                  object
# trailer_id                object
# dispatch_date             object
# actual_distance_miles      int64
# actual_duration_hours    float64
# fuel_litres              float64
# average_mpl              float64
# idle_time_hours          float64
# trip_status               object
# dtype: object
#             trip_id       load_id driver_id  truck_id trailer_id  \
# ...

# %%
delivery_events
# Out:
#            event_id       load_id       trip_id event_type facility_id  \
# 0       EVT00000001  LOAD00000001  TRIP00000001     Pickup    FAC00034
# 1       EVT00000002  LOAD00000001  TRIP00000001   Delivery    FAC00046
# 2       EVT00000003  LOAD00000002  TRIP00000002     Pickup    FAC00015
# 3       EVT00000004  LOAD00000002  TRIP00000002   Delivery    FAC00050
# 4       EVT00000005  LOAD00000003  TRIP00000003     Pickup    FAC00001
# ...             ...           ...           ...        ...         ...
# 170815  EVT00170816  LOAD00085408  TRIP00085408   Delivery    FAC00045
# 170816  EVT00170817  LOAD00085409  TRIP00085409     Pickup    FAC00025
# 170817  EVT00170818  LOAD00085409  TRIP00085409   Delivery    FAC00001
# 170818  EVT00170819  LOAD00085410  TRIP00085410     Pickup    FAC00027
# 170819  EVT00170820  LOAD00085410  TRIP00085410   Delivery    FAC00019
#
#                 scheduled_datetime             actual_datetime  \
# ...

# %%
# Data cleaning (delivery_events)
print(f"isna:\n{delivery_events.isna().sum()}")
print(f"duplicated:\n{delivery_events.duplicated().sum()}")
print(f"dtypes:\n{delivery_events.dtypes}")
print(f"event_type:\n{delivery_events['event_type'].unique()}")
print(f"location_city:\n{delivery_events['location_city'].unique()}")
delivery_events["scheduled_datetime"] = pd.to_datetime(delivery_events["scheduled_datetime"])
delivery_events["actual_datetime"] = pd.to_datetime(delivery_events["actual_datetime"])
print(delivery_events.dtypes)
# Out:
# isna:
# event_id              0
# load_id               0
# trip_id               0
# event_type            0
# facility_id           0
# scheduled_datetime    0
# actual_datetime       0
# detention_minutes     0
# on_time_flag          0
# location_city         0
# location_state        0
# dtype: int64
# duplicated:
# 0
# dtypes:
# event_id              object
# load_id               object
# trip_id               object
# event_type            object
# facility_id           object
# scheduled_datetime    object
# actual_datetime       object
# detention_minutes      int64
# on_time_flag            bool
# location_city         object
# location_state        object
# dtype: object
# event_type:
# ['Pickup' 'Delivery']
# location_city:
# ['Houston' 'Detroit' 'Kansas City' 'Indianapolis' 'Columbus' 'Portland'
#  'Phoenix' 'Denver' 'Seattle' 'Chicago' 'Las Vegas' 'Philadelphia' 'Miami'
#  'Memphis' 'Minneapolis' 'Atlanta' 'Charlotte' 'New York' 'Los Angeles'
#  'Dallas']
# ...

# %%
fuel_purchases
# Out:
#        fuel_purchase_id       trip_id  truck_id driver_id  \
# 0          FUEL00000001  TRIP00051284  TRK00045  DRV00102
# 1          FUEL00000002  TRIP00073723  TRK00013       NaN
# 2          FUEL00000003  TRIP00018286  TRK00024  DRV00142
# 3          FUEL00000004  TRIP00008465  TRK00018  DRV00047
# 4          FUEL00000005  TRIP00069700  TRK00054       NaN
# ...                 ...           ...       ...       ...
# 196437     FUEL00196438  TRIP00065465  TRK00030  DRV00030
# 196438     FUEL00196439  TRIP00026022  TRK00044  DRV00035
# 196439     FUEL00196440  TRIP00074799  TRK00053  DRV00126
# 196440     FUEL00196441  TRIP00031314  TRK00065  DRV00085
# 196441     FUEL00196442  TRIP00076016  TRK00026  DRV00065
#
#               purchase_date location_city location_state  gallons  \
# 0       2023-10-22 05:00:00      Columbus             MN    131.6
# 1       2024-08-04 08:00:00      New York             AZ    139.9
# 2       2022-08-23 13:00:00       Seattle             NE    189.3
# ...

# %%
#Data Exploration (Fuel Purchases)

print(f"isna:\n{fuel_purchases.isna().sum()}")
print(f"duplicated:\n{fuel_purchases.duplicated().sum()}")
print(f"dtypes:\n{fuel_purchases.dtypes}")
print(fuel_purchases[fuel_purchases["truck_id"].isna()])
print(fuel_purchases[fuel_purchases["driver_id"].isna()])
fuel_purchases["truck_id"] = fuel_purchases["truck_id"].fillna("Unknown")
fuel_purchases["driver_id"] = fuel_purchases["driver_id"].fillna("Unknown")
fuel_purchases["purchase_date"] = pd.to_datetime(fuel_purchases["purchase_date"])
print(fuel_purchases.isna().sum())
print(fuel_purchases.dtypes)
# Out:
# isna:
# fuel_purchase_id       0
# trip_id                0
# truck_id            3880
# driver_id           3988
# purchase_date          0
# location_city          0
# location_state         0
# gallons                0
# price_per_gallon       0
# total_cost             0
# fuel_card_number       0
# dtype: int64
# duplicated:
# 0
# dtypes:
# fuel_purchase_id     object
# trip_id              object
# truck_id             object
# driver_id            object
# purchase_date        object
# location_city        object
# location_state       object
# gallons             float64
# price_per_gallon    float64
# total_cost          float64
# fuel_card_number     object
# dtype: object
#        fuel_purchase_id       trip_id truck_id driver_id        purchase_date  \
# 11         FUEL00000012  TRIP00079405      NaN  DRV00085  2024-10-16 19:00:00
# 37         FUEL00000038  TRIP00036457      NaN  DRV00020  2023-04-12 11:00:00
# ...

# %%
#Data Exploration (maintance_records)

print(f"isna:\n{maintenance_records.isna().sum()}")
print(f"duplicated:\n{maintenance_records.duplicated().sum()}")
print(f"dtypes:\n{maintenance_records.dtypes}")
maintenance_records["maintenance_date"] = pd.to_datetime(maintenance_records["maintenance_date"])
# Out:
# isna:
# maintenance_id         0
# truck_id               0
# maintenance_date       0
# maintenance_type       0
# odometer_reading       0
# labor_hours            0
# labor_cost             0
# parts_cost             0
# total_cost             0
# facility_location      0
# downtime_hours         0
# service_description    0
# dtype: int64
# duplicated:
# 0
# dtypes:
# maintenance_id          object
# truck_id                object
# maintenance_date        object
# maintenance_type        object
# odometer_reading         int64
# labor_hours            float64
# labor_cost             float64
# parts_cost             float64
# total_cost             float64
# facility_location       object
# downtime_hours         float64
# service_description     object
# dtype: object

# %%
#Data Exploration (driver_monthly)

print(f"isna:\n{driver_monthly_metrics.isna().sum()}")
print(f"duplicated:\n{driver_monthly_metrics.duplicated().sum()}")
print(f"dtypes:\n{driver_monthly_metrics.dtypes}")
# Out:
# isna:
# driver_id                0
# month                    0
# trips_completed          0
# total_miles              0
# total_revenue            0
# average_mpg              0
# total_fuel_gallons       0
# on_time_delivery_rate    0
# average_idle_hours       0
# dtype: int64
# duplicated:
# 0
# dtypes:
# driver_id                 object
# month                     object
# trips_completed            int64
# total_miles                int64
# total_revenue            float64
# average_mpg              float64
# total_fuel_gallons       float64
# on_time_delivery_rate    float64
# average_idle_hours       float64
# dtype: object

# %%
#Data Exploration (truck_utilization_metric)

print(f"isna:\n{truck_utilization_metrics.isna().sum()}")
print(f"duplicated:\n{truck_utilization_metrics.duplicated().sum()}")
print(f"dtypes:\n{truck_utilization_metrics.dtypes}")
# Out:
# isna:
# truck_id              0
# month                 0
# trips_completed       0
# total_miles           0
# total_revenue         0
# average_mpg           0
# maintenance_events    0
# maintenance_cost      0
# downtime_hours        0
# utilization_rate      0
# dtype: int64
# duplicated:
# 0
# dtypes:
# truck_id               object
# month                  object
# trips_completed         int64
# total_miles             int64
# total_revenue         float64
# average_mpg           float64
# maintenance_events      int64
# maintenance_cost      float64
# downtime_hours        float64
# utilization_rate      float64
# dtype: object

# %%
#data cleaning (safety_incident)

print(f"isna:\n{safety_incidents.isna().sum()}")
print(f"duplicated:\n{safety_incidents.duplicated().sum()}")
print(f"dtypes:\n{safety_incidents.dtypes}")
print(safety_incidents[safety_incidents["truck_id"].isna()])
print(safety_incidents[safety_incidents["driver_id"].isna()])
safety_incidents["truck_id"] = safety_incidents["truck_id"].fillna("Unknown")
safety_incidents["driver_id"] = safety_incidents["driver_id"].fillna("Unknown")
print(safety_incidents.isna().sum())
print(safety_incidents.dtypes)
# Out:
# isna:
# incident_id            0
# trip_id                0
# truck_id               1
# driver_id              1
# incident_date          0
# incident_type          0
# location_city          0
# location_state         0
# at_fault_flag          0
# injury_flag            0
# vehicle_damage_cost    0
# cargo_damage_cost      0
# claim_amount           0
# preventable_flag       0
# description            0
# dtype: int64
# duplicated:
# 0
# dtypes:
# incident_id             object
# trip_id                 object
# truck_id                object
# driver_id               object
# incident_date           object
# incident_type           object
# location_city           object
# location_state          object
# at_fault_flag             bool
# injury_flag               bool
# vehicle_damage_cost    float64
# cargo_damage_cost      float64
# claim_amount           float64
# preventable_flag          bool
# description             object
# dtype: object
# ...

# %%
customers
# Out:
#     customer_id          customer_name customer_type  credit_terms_days  \
# 0     CUST00001        Metro Wholesale     Dedicated                 60
# 1     CUST00002        National Retail      Contract                 30
# 2     CUST00003         XYZ Industries      Contract                 30
# 3     CUST00004          American Corp      Contract                 15
# 4     CUST00005  American Distribution          Spot                 45
# ..          ...                    ...           ...                ...
# 195   CUST00196          XYZ Logistics          Spot                 60
# 196   CUST00197               ABC Corp      Contract                 15
# 197   CUST00198        Elite Wholesale     Dedicated                 60
# 198   CUST00199            First Group      Contract                 15
# 199   CUST00200              XYZ Foods     Dedicated                 45
#
#     primary_freight_type account_status contract_start_date  \
# ...

# %%
loads
# Out:
#             load_id customer_id  route_id  load_date     load_type  \
# 0      LOAD00000001   CUST00183  RTE00019 2022-01-01       Dry Van
# 1      LOAD00000002   CUST00076  RTE00058 2022-01-01       Dry Van
# 2      LOAD00000003   CUST00027  RTE00048 2022-01-01  Refrigerated
# 3      LOAD00000004   CUST00088  RTE00013 2022-01-01  Refrigerated
# 4      LOAD00000005   CUST00185  RTE00020 2022-01-01       Dry Van
# ...             ...         ...       ...        ...           ...
# 85405  LOAD00085406   CUST00016  RTE00039 2024-12-31  Refrigerated
# 85406  LOAD00085407   CUST00179  RTE00008 2024-12-31       Dry Van
# 85407  LOAD00085408   CUST00136  RTE00056 2024-12-31  Refrigerated
# 85408  LOAD00085409   CUST00012  RTE00016 2024-12-31  Refrigerated
# 85409  LOAD00085410   CUST00169  RTE00007 2024-12-31       Dry Van
#
#        weight_lbs  pieces  revenue  fuel_surcharge  accessorial_charges  \
# 0           19178      13  3045.23          406.72                  100
# ...

# %%
#filtering(customers & loads)

customer_loads = pd.merge(loads,customers,on="customer_id",how="inner")                                                          #INNER → common mattum ,LEFT  → left table full,RIGHT → right table full,OUTER → rendu table full

print(customer_loads)
active_customer_loads = customer_loads[customer_loads["account_status"] == "Active"]
print(active_customer_loads) 
revenue = (active_customer_loads.groupby("customer_type")["revenue"].sum())
revenue = revenue.sort_values(ascending=False)
# Out:
#             load_id customer_id  route_id  load_date     load_type  \
# 0      LOAD00000001   CUST00183  RTE00019 2022-01-01       Dry Van
# 1      LOAD00000002   CUST00076  RTE00058 2022-01-01       Dry Van
# 2      LOAD00000003   CUST00027  RTE00048 2022-01-01  Refrigerated
# 3      LOAD00000004   CUST00088  RTE00013 2022-01-01  Refrigerated
# 4      LOAD00000005   CUST00185  RTE00020 2022-01-01       Dry Van
# ...             ...         ...       ...        ...           ...
# 85405  LOAD00085406   CUST00016  RTE00039 2024-12-31  Refrigerated
# 85406  LOAD00085407   CUST00179  RTE00008 2024-12-31       Dry Van
# 85407  LOAD00085408   CUST00136  RTE00056 2024-12-31  Refrigerated
# 85408  LOAD00085409   CUST00012  RTE00016 2024-12-31  Refrigerated
# 85409  LOAD00085410   CUST00169  RTE00007 2024-12-31       Dry Van
#
#        weight_lbs  pieces  revenue  fuel_surcharge  accessorial_charges  \
# 0           19178      13  3045.23          406.72                  100
# ...

# %%
#chart(customers & loads)

sns.barplot(x=revenue.index, y=revenue.values,  palette=["blue", "red", "green"])
plt.title("Actual Revenue by Active Customer Type", fontsize=16)
plt.xlabel("Customer Type", fontsize=12)
plt.ylabel("Total Revenue", fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis="y", linestyle="-", alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MOHAMEDSHAFITH\AppData\Local\Temp\ipykernel_22400\2076434466.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=revenue.index, y=revenue.values,  palette=["blue", "red", "green"])

# %%
routes
# Out:
#     route_id   origin_city origin_state destination_city destination_state  \
# 0   RTE00001       Atlanta           GA          Chicago                IL
# 1   RTE00002       Atlanta           GA            Miami                FL
# 2   RTE00003       Chicago           IL      Los Angeles                CA
# 3   RTE00004       Chicago           IL         Portland                OR
# 4   RTE00005       Chicago           IL        Las Vegas                NV
# 5   RTE00006       Chicago           IL        Charlotte                NC
# 6   RTE00007        Dallas           TX         New York                NY
# 7   RTE00008        Dallas           TX           Denver                CO
# 8   RTE00009        Dallas           TX     Indianapolis                IN
# 9   RTE00010      New York           NY     Philadelphia                PA
# 10  RTE00011      New York           NY         Columbus                OH
# ...

# %%
loads
# Out:
#             load_id customer_id  route_id  load_date     load_type  \
# 0      LOAD00000001   CUST00183  RTE00019 2022-01-01       Dry Van
# 1      LOAD00000002   CUST00076  RTE00058 2022-01-01       Dry Van
# 2      LOAD00000003   CUST00027  RTE00048 2022-01-01  Refrigerated
# 3      LOAD00000004   CUST00088  RTE00013 2022-01-01  Refrigerated
# 4      LOAD00000005   CUST00185  RTE00020 2022-01-01       Dry Van
# ...             ...         ...       ...        ...           ...
# 85405  LOAD00085406   CUST00016  RTE00039 2024-12-31  Refrigerated
# 85406  LOAD00085407   CUST00179  RTE00008 2024-12-31       Dry Van
# 85407  LOAD00085408   CUST00136  RTE00056 2024-12-31  Refrigerated
# 85408  LOAD00085409   CUST00012  RTE00016 2024-12-31  Refrigerated
# 85409  LOAD00085410   CUST00169  RTE00007 2024-12-31       Dry Van
#
#        weight_lbs  pieces  revenue  fuel_surcharge  accessorial_charges  \
# 0           19178      13  3045.23          406.72                  100
# ...

# %%
# 2-filtering(routes & loads) 
route_loads = pd.merge(routes, loads, on="route_id", how="inner")
print(route_loads)
route_revenue = route_loads.groupby("route_id")["revenue"].sum()
revenue = route_revenue.sort_values(ascending=False)
print(revenue)
# Out:
#        route_id  origin_city origin_state destination_city destination_state  \
# 0      RTE00001      Atlanta           GA          Chicago                IL
# 1      RTE00001      Atlanta           GA          Chicago                IL
# 2      RTE00001      Atlanta           GA          Chicago                IL
# 3      RTE00001      Atlanta           GA          Chicago                IL
# 4      RTE00001      Atlanta           GA          Chicago                IL
# ...         ...          ...          ...              ...               ...
# 85405  RTE00058  Kansas City           MO     Indianapolis                IN
# 85406  RTE00058  Kansas City           MO     Indianapolis                IN
# 85407  RTE00058  Kansas City           MO     Indianapolis                IN
# 85408  RTE00058  Kansas City           MO     Indianapolis                IN
# 85409  RTE00058  Kansas City           MO     Indianapolis                IN
#
# ...

# %%
route_names = routes[["route_id", "origin_city", "destination_city"]]                                                                                                                                                                  #route id bathila route name mathurom so three columns eduturukka
route_names["route_name"] = (route_names["origin_city"] + " → " + route_names["destination_city"])                                                                                                                                     #Left side = enna new column create pannanum // Right side = andha new column-ku values enga irundhu edukkanum
print(route_names)
# Out:
#     route_id   origin_city destination_city                   route_name
# 0   RTE00001       Atlanta          Chicago            Atlanta → Chicago
# 1   RTE00002       Atlanta            Miami              Atlanta → Miami
# 2   RTE00003       Chicago      Los Angeles        Chicago → Los Angeles
# 3   RTE00004       Chicago         Portland           Chicago → Portland
# 4   RTE00005       Chicago        Las Vegas          Chicago → Las Vegas
# 5   RTE00006       Chicago        Charlotte          Chicago → Charlotte
# 6   RTE00007        Dallas         New York            Dallas → New York
# 7   RTE00008        Dallas           Denver              Dallas → Denver
# 8   RTE00009        Dallas     Indianapolis        Dallas → Indianapolis
# 9   RTE00010      New York     Philadelphia      New York → Philadelphia
# 10  RTE00011      New York         Columbus          New York → Columbus
# 11  RTE00012       Phoenix     Philadelphia       Phoenix → Philadelphia
# ...

# %%
route_revenue = pd.merge(
    revenue.reset_index(),                                                                                                                                                                                                         #Index-aa irukkura route_id-ai normal column-aa maathum adukaga reset index poturuka
    route_names[["route_id", "route_name"]],on="route_id",how="inner")                                                                                                                                                             #inga revenue  and route_names nu dataframe .route_name la specific rendu column call panni revenue la irukura rendu column plus idula ulla rendu column merge pannurom 
top_10_routes = route_revenue.head(10)
print(route_revenue)
print(top_10_routes)
# Out:
#     route_id      revenue                   route_name
# 0   RTE00016  10069054.22       Philadelphia → Seattle
# 1   RTE00044   9979091.72         Charlotte → Portland
# 2   RTE00012   9757537.38       Phoenix → Philadelphia
# 3   RTE00048   9586536.90          Columbus → Portland
# 4   RTE00029   9516077.71          Seattle → Charlotte
# 5   RTE00046   9501202.04       Columbus → Los Angeles
# 6   RTE00042   9070885.01          Charlotte → Seattle
# 7   RTE00030   7681556.33       Seattle → Indianapolis
# 8   RTE00003   7621380.80        Chicago → Los Angeles
# 9   RTE00021   7595328.46           Houston → Portland
# 10  RTE00025   7523007.13              Miami → Seattle
# 11  RTE00034   7264971.31          Portland → Columbus
# 12  RTE00032   6621835.80           Portland → Detroit
# 13  RTE00005   6236094.68          Chicago → Las Vegas
# 14  RTE00056   6234118.29       Kansas City → Portland
# 15  RTE00028   6233044.36            Seattle → Houston
# ...

# %%
#chart(routes &  loads)
plt.figure(figsize=(14, 6))
sns.barplot(x=top_10_routes["route_name"],y=top_10_routes["revenue"],
            palette=(["blue", "orange", "green", "red", "purple","brown", "pink", "gray", "olive", "cyan"]))
for i,value in enumerate(top_10_routes["revenue"]):
    plt.text(i,value,f"{value:.2f}",ha="center")                     # idu venum na katalam illa remove pannidalam
plt.title("Top 10 Routes by Total Revenue", fontsize=16)
plt.xlabel("Route")
plt.ylabel("Total Revenue")
plt.xticks(rotation=45, ha="right")
plt.grid(axis="y", linestyle="-.", alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MOHAMEDSHAFITH\AppData\Local\Temp\ipykernel_22400\3537581325.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_routes["route_name"],y=top_10_routes["revenue"],

# %%
trips
# Out:
#             trip_id       load_id driver_id  truck_id trailer_id  \
# 0      TRIP00000001  LOAD00000001  DRV00117  TRK00035   TRL00167
# 1      TRIP00000002  LOAD00000002  DRV00141  TRK00108   TRL00082
# 2      TRIP00000003  LOAD00000003  DRV00032  TRK00031   TRL00138
# 3      TRIP00000004  LOAD00000004  DRV00083  TRK00105   TRL00018
# 4      TRIP00000005  LOAD00000005  DRV00044  TRK00076   TRL00054
# ...             ...           ...       ...       ...        ...
# 85405  TRIP00085406  LOAD00085406  DRV00005  TRK00029   TRL00058
# 85406  TRIP00085407  LOAD00085407  DRV00091  TRK00080   TRL00092
# 85407  TRIP00085408  LOAD00085408  DRV00011  TRK00051   TRL00083
# 85408  TRIP00085409  LOAD00085409  DRV00094  TRK00073   TRL00137
# 85409  TRIP00085410  LOAD00085410  DRV00049  TRK00099   TRL00033
#
#       dispatch_date  actual_distance_miles  actual_duration_hours  \
# 0        2022-01-01                   1314                   26.2
# ...

# %%
#Loads + Trips
load_trips = pd.merge(loads, trips, on="load_id", how="inner")
print(load_trips)
print(load_trips[["actual_distance_miles", "fuel_litres"]].describe())
# Out:
#             load_id customer_id  route_id  load_date     load_type  \
# 0      LOAD00000001   CUST00183  RTE00019 2022-01-01       Dry Van
# 1      LOAD00000002   CUST00076  RTE00058 2022-01-01       Dry Van
# 2      LOAD00000003   CUST00027  RTE00048 2022-01-01  Refrigerated
# 3      LOAD00000004   CUST00088  RTE00013 2022-01-01  Refrigerated
# 4      LOAD00000005   CUST00185  RTE00020 2022-01-01       Dry Van
# ...             ...         ...       ...        ...           ...
# 85405  LOAD00085406   CUST00016  RTE00039 2024-12-31  Refrigerated
# 85406  LOAD00085407   CUST00179  RTE00008 2024-12-31       Dry Van
# 85407  LOAD00085408   CUST00136  RTE00056 2024-12-31  Refrigerated
# 85408  LOAD00085409   CUST00012  RTE00016 2024-12-31  Refrigerated
# 85409  LOAD00085410   CUST00169  RTE00007 2024-12-31       Dry Van
#
#        weight_lbs  pieces  revenue  fuel_surcharge  accessorial_charges  ...  \
# 0           19178      13  3045.23          406.72                  100  ...
# ...

# %%
sns.scatterplot(
    x=load_trips["actual_distance_miles"], y=load_trips["fuel_litres"])
plt.title("Trip Distance vs Fuel Consumption", fontsize=16)
plt.xlabel("Actual Distance (Miles)", fontsize=12)
plt.ylabel("Fuel Consumption (Litres)", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
drivers
# Out:
#     driver_id first_name  last_name   hire_date termination_date  \
# 0    DRV00001   Jennifer  Hernandez  2014-10-31              NaN
# 1    DRV00002    William     Martin  2020-10-02              NaN
# 2    DRV00003    Charles  Hernandez  2021-09-21              NaN
# 3    DRV00004    Barbara      Brown  2013-09-08              NaN
# 4    DRV00005       Mary   Martinez  2018-12-02              NaN
# ..        ...        ...        ...         ...              ...
# 145  DRV00146    Jessica   Gonzalez  2019-01-13              NaN
# 146  DRV00147    Richard     Garcia  2020-06-09              NaN
# 147  DRV00148   Patricia   Anderson  2019-03-28              NaN
# 148  DRV00149      Linda      Jones  2013-08-25              NaN
# 149  DRV00150     Robert     Martin  2015-09-16              NaN
#
#     license_number license_state date_of_birth   home_terminal  \
# 0      DL673510887            WA    1973-11-07          Denver
# ...

# %%
driver_monthly_metrics
# Out:
#      driver_id       month  trips_completed  total_miles  total_revenue  \
# 0     DRV00001  2022-01-01               26        36620       79141.59
# 1     DRV00001  2022-02-01                9        13515       27133.87
# 2     DRV00001  2022-03-01               20        30361       62399.62
# 3     DRV00001  2022-04-01               19        28127       68161.13
# 4     DRV00001  2022-05-01               14        16071       36256.82
# ...        ...         ...              ...          ...            ...
# 4459  DRV00150  2024-08-01               22        33432       68220.59
# 4460  DRV00150  2024-09-01               25        38537       73609.79
# 4461  DRV00150  2024-10-01               27        38919       86802.35
# 4462  DRV00150  2024-11-01               19        24256       51483.57
# 4463  DRV00150  2024-12-01               14        21484       45774.78
#
#       average_mpg  total_fuel_gallons  on_time_delivery_rate  \
# ...

# %%
#Drivers& Driver_Monthly_Metrics

driver_performance = pd.merge(drivers,driver_monthly_metrics,on="driver_id", how="inner")
print(driver_performance)
driver_revenue = driver_performance.groupby(["driver_id", "years_experience"])["total_revenue"].sum()                                                                                                                              #"Same driver ID-um same experience-um irukkura records-ai oru group-aa collect pannu."
driver_revenue = driver_revenue.sort_values(ascending=False)
driver_revenue = driver_revenue.reset_index()
print(driver_revenue)
# Out:
#      driver_id first_name  last_name   hire_date termination_date  \
# 0     DRV00001   Jennifer  Hernandez  2014-10-31              NaN
# 1     DRV00001   Jennifer  Hernandez  2014-10-31              NaN
# 2     DRV00001   Jennifer  Hernandez  2014-10-31              NaN
# 3     DRV00001   Jennifer  Hernandez  2014-10-31              NaN
# 4     DRV00001   Jennifer  Hernandez  2014-10-31              NaN
# ...        ...        ...        ...         ...              ...
# 4459  DRV00150     Robert     Martin  2015-09-16              NaN
# 4460  DRV00150     Robert     Martin  2015-09-16              NaN
# 4461  DRV00150     Robert     Martin  2015-09-16              NaN
# 4462  DRV00150     Robert     Martin  2015-09-16              NaN
# 4463  DRV00150     Robert     Martin  2015-09-16              NaN
#
#      license_number license_state date_of_birth home_terminal  \
# 0       DL673510887            WA    1973-11-07        Denver
# ...

# %%
print(driver_revenue)
# Out:
#     driver_id  years_experience  total_revenue
# 0    DRV00051                12     2311844.30
# 1    DRV00108                23     2311327.90
# 2    DRV00059                 4     2305056.60
# 3    DRV00016                11     2278574.88
# 4    DRV00019                20     2275654.76
# ..        ...               ...            ...
# 119  DRV00091                17     1867304.47
# 120  DRV00122                12     1863824.04
# 121  DRV00064                 4     1859390.39
# 122  DRV00080                 3     1837156.85
# 123  DRV00012                25     1749865.66
#
# [124 rows x 3 columns]

# %%
sns.scatterplot(x=driver_revenue["years_experience"], y=driver_revenue["total_revenue"])  #y la irukuradu millions la varudu
plt.title("Driver Experience vs Total Revenue", fontsize=16)
plt.xlabel("Years of Experience", fontsize=12)
plt.ylabel("Total Revenue", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
truck_utilization_metrics
# Out:
#       truck_id       month  trips_completed  total_miles  total_revenue  \
# 0     TRK00001  2022-01-01               22        39269       84792.02
# 1     TRK00001  2022-02-01               27        40787       88809.05
# 2     TRK00001  2022-03-01               34        57422      120453.71
# 3     TRK00001  2022-04-01               20        34428       73531.28
# 4     TRK00001  2022-05-01               16        20851       40791.53
# ...        ...         ...              ...          ...            ...
# 3307  TRK00120  2024-08-01               15        19931       47939.96
# 3308  TRK00120  2024-09-01               20        29583       64748.71
# 3309  TRK00120  2024-10-01               20        22229       49688.65
# 3310  TRK00120  2024-11-01               25        38435       78366.23
# 3311  TRK00120  2024-12-01               18        22642       50482.64
#
#       average_mpg  maintenance_events  maintenance_cost  downtime_hours  \
# ...

# %%
#Truck Monthly Metrics
print(truck_utilization_metrics[["utilization_rate", "total_revenue"]].describe())
# Out:
#        utilization_rate  total_revenue
# count       3312.000000    3312.000000
# mean           0.830447   77700.561564
# std            0.166084   17995.268042
# min            0.387000   27876.180000
# 25%            0.710000   65213.702500
# 50%            0.833000   76607.690000
# 75%            0.935000   89556.515000
# max            1.484000  144891.100000

# %%
sns.scatterplot(
    x=truck_utilization_metrics["utilization_rate"],
    y=truck_utilization_metrics["total_revenue"])
plt.title("Truck Utilization vs Total Revenue", fontsize=16)
plt.xlabel("Utilization Rate", fontsize=12)
plt.ylabel("Total Revenue", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
trips
# Out:
#             trip_id       load_id driver_id  truck_id trailer_id  \
# 0      TRIP00000001  LOAD00000001  DRV00117  TRK00035   TRL00167
# 1      TRIP00000002  LOAD00000002  DRV00141  TRK00108   TRL00082
# 2      TRIP00000003  LOAD00000003  DRV00032  TRK00031   TRL00138
# 3      TRIP00000004  LOAD00000004  DRV00083  TRK00105   TRL00018
# 4      TRIP00000005  LOAD00000005  DRV00044  TRK00076   TRL00054
# ...             ...           ...       ...       ...        ...
# 85405  TRIP00085406  LOAD00085406  DRV00005  TRK00029   TRL00058
# 85406  TRIP00085407  LOAD00085407  DRV00091  TRK00080   TRL00092
# 85407  TRIP00085408  LOAD00085408  DRV00011  TRK00051   TRL00083
# 85408  TRIP00085409  LOAD00085409  DRV00094  TRK00073   TRL00137
# 85409  TRIP00085410  LOAD00085410  DRV00049  TRK00099   TRL00033
#
#       dispatch_date  actual_distance_miles  actual_duration_hours  \
# 0        2022-01-01                   1314                   26.2
# ...

# %%
fuel_purchases
# Out:
#        fuel_purchase_id       trip_id  truck_id driver_id       purchase_date  \
# 0          FUEL00000001  TRIP00051284  TRK00045  DRV00102 2023-10-22 05:00:00
# 1          FUEL00000002  TRIP00073723  TRK00013   Unknown 2024-08-04 08:00:00
# 2          FUEL00000003  TRIP00018286  TRK00024  DRV00142 2022-08-23 13:00:00
# 3          FUEL00000004  TRIP00008465  TRK00018  DRV00047 2022-04-20 00:00:00
# 4          FUEL00000005  TRIP00069700  TRK00054   Unknown 2024-06-13 09:00:00
# ...                 ...           ...       ...       ...                 ...
# 196437     FUEL00196438  TRIP00065465  TRK00030  DRV00030 2024-04-22 23:00:00
# 196438     FUEL00196439  TRIP00026022  TRK00044  DRV00035 2022-11-28 21:00:00
# 196439     FUEL00196440  TRIP00074799  TRK00053  DRV00126 2024-08-19 22:00:00
# 196440     FUEL00196441  TRIP00031314  TRK00065  DRV00085 2023-02-06 05:00:00
# 196441     FUEL00196442  TRIP00076016  TRK00026  DRV00065 2024-09-04 06:00:00
#
# ...

# %%
#fuel_purchases

fuel_purchases.info()
fuel_purchases["purchase_date"] = pd.to_datetime(fuel_purchases["purchase_date"])
print(fuel_purchases)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196442 entries, 0 to 196441
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   fuel_purchase_id  196442 non-null  object
#  1   trip_id           196442 non-null  object
#  2   truck_id          196442 non-null  object
#  3   driver_id         196442 non-null  object
#  4   purchase_date     196442 non-null  datetime64[ns]
#  5   location_city     196442 non-null  object
#  6   location_state    196442 non-null  object
#  7   gallons           196442 non-null  float64
#  8   price_per_gallon  196442 non-null  float64
#  9   total_cost        196442 non-null  float64
#  10  fuel_card_number  196442 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(7)
# memory usage: 16.5+ MB
#        fuel_purchase_id       trip_id  truck_id driver_id       purchase_date  \
# ...

# %%
monthly_fuel_cost = fuel_purchases.groupby(fuel_purchases["purchase_date"].dt.to_period("M"))["total_cost"] .sum()   
print(monthly_fuel_cost)         # “Indha dates-la exact day/time thevai illa; year + month ^^mattum consider pannu
# Out:
# purchase_date
# 2022-01    2822857.10
# 2022-02    2601024.90
# 2022-03    2855264.99
# 2022-04    2857719.10
# 2022-05    2881461.91
# 2022-06    2815372.68
# 2022-07    2922198.68
# 2022-08    3093596.71
# 2022-09    2788561.01
# 2022-10    3009586.07
# 2022-11    2837716.28
# 2022-12    2859819.46
# 2023-01    2625414.70
# 2023-02    2361398.05
# 2023-03    2757842.58
# 2023-04    2542577.45
# 2023-05    2549762.62
# 2023-06    2566581.79
# 2023-07    2762248.00
# 2023-08    2577436.48
# 2023-09    2568924.14
# 2023-10    2603655.77
# 2023-11    2598664.01
# 2023-12    2558613.98
# 2024-01    2518064.87
# 2024-02    2367414.23
# 2024-03    2567952.34
# 2024-04    2498008.27
# 2024-05    2608498.10
# 2024-06    2513030.04
# 2024-07    2532598.08
# 2024-08    2512518.06
# 2024-09    2440501.75
# 2024-10    2619832.28
# 2024-11    2438131.27
# 2024-12    2464875.39
# 2025-01      93268.90
# Freq: M, Name: total_cost, dtype: float64

# %%
plt.figure(figsize=(15, 6))

sns.lineplot(
    x=monthly_fuel_cost.index.astype(str),                                                                                                                            # (str)Andha month values-ai string/text-aa convert pannum.
    y=monthly_fuel_cost.values)
for i ,value in enumerate(monthly_fuel_cost.values):
    plt.text(i,value,f"{value:.2f}",ha="center")
plt.title("Monthly Fuel Cost Trend", fontsize=16)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Total Fuel Cost", fontsize=12)
plt.xticks(rotation=45)
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
maintenance_records
# Out:
#      maintenance_id  truck_id maintenance_date maintenance_type  \
# 0     MAINT00000001  TRK00085       2022-01-01       Inspection
# 1     MAINT00000002  TRK00041       2022-01-01             Tire
# 2     MAINT00000003  TRK00090       2022-01-01       Preventive
# 3     MAINT00000004  TRK00056       2022-01-02       Inspection
# 4     MAINT00000005  TRK00029       2022-01-02           Repair
# ...             ...       ...              ...              ...
# 2915  MAINT00002916  TRK00073       2024-12-30       Inspection
# 2916  MAINT00002917  TRK00044       2024-12-31       Preventive
# 2917  MAINT00002918  TRK00066       2024-12-31           Repair
# 2918  MAINT00002919  TRK00093       2024-12-31           Engine
# 2919  MAINT00002920  TRK00086       2024-12-31             Tire
#
#       odometer_reading  labor_hours  labor_cost  parts_cost  total_cost  \
# 0               400255          7.8      781.42       10.41      791.83
# ...

# %%
#Maintenance

maintenance_cost = (maintenance_records .groupby("maintenance_type")["total_cost"].sum())
maintenance_cost = maintenance_cost.sort_values(ascending=False)
print(maintenance_cost)
# Out:
# maintenance_type
# Preventive      963576.34
# Repair          945375.44
# Tire            919413.24
# Brake           911667.23
# Engine          890537.88
# Transmission    879620.87
# Inspection      220382.28
# Name: total_cost, dtype: float64

# %%
plt.figure(figsize=(5,5))

plt.pie(
    maintenance_cost.values,
    labels=maintenance_cost.index,
    autopct="%1.1f%%",
    startangle=90)

plt.title("Maintenance Cost Distribution", fontsize=16)
plt.tight_layout()
plt.show()

# %%
delivery_events
# Out:
#            event_id       load_id       trip_id event_type facility_id  \
# 0       EVT00000001  LOAD00000001  TRIP00000001     Pickup    FAC00034
# 1       EVT00000002  LOAD00000001  TRIP00000001   Delivery    FAC00046
# 2       EVT00000003  LOAD00000002  TRIP00000002     Pickup    FAC00015
# 3       EVT00000004  LOAD00000002  TRIP00000002   Delivery    FAC00050
# 4       EVT00000005  LOAD00000003  TRIP00000003     Pickup    FAC00001
# ...             ...           ...           ...        ...         ...
# 170815  EVT00170816  LOAD00085408  TRIP00085408   Delivery    FAC00045
# 170816  EVT00170817  LOAD00085409  TRIP00085409     Pickup    FAC00025
# 170817  EVT00170818  LOAD00085409  TRIP00085409   Delivery    FAC00001
# 170818  EVT00170819  LOAD00085410  TRIP00085410     Pickup    FAC00027
# 170819  EVT00170820  LOAD00085410  TRIP00085410   Delivery    FAC00019
#
#                scheduled_datetime            actual_datetime  \
# ...

# %%
#delivery_events

on_time_performance = (
    delivery_events.groupby("event_type")["on_time_flag"].mean() * 100)   # mean la vara values *100 panna appadiya percentage maarirum 
print(on_time_performance)
# Out:
# event_type
# Delivery    44.610701
# Pickup      66.728720
# Name: on_time_flag, dtype: float64

# %%
sns.barplot(
    x=on_time_performance.index,
    y=on_time_performance.values)
for i,value in enumerate(on_time_performance.values):
    plt.text(
        i,value,f"{value:.2f}",ha="center"
    )
plt.title("On-Time Performance by Event Type", fontsize=16)
plt.xlabel("Event Type", fontsize=12)
plt.ylabel("On-Time Percentage", fontsize=12)
plt.tight_layout()
plt.show()

# %%
#Safety Incidents

incident_count = safety_incidents["incident_type"].value_counts()
print(incident_count)
# Out:
# incident_type
# DOT Violation         39
# Equipment Damage      35
# Accident              35
# Customer Complaint    34
# Moving Violation      27
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
plt.pie(
    incident_count.values,
    labels=incident_count.index,
    autopct="%1.1f%%",                                                                                                                                                                                                               #plt.pie() automatically andha counts-ai total-la percentage share-aa convert panni autopct moolama display pannum
    startangle=90)
plt.title("Safety Incident Distribution", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Driver Monthly Performance

driver_ontime = (driver_monthly_metrics.groupby("driver_id")["on_time_delivery_rate"].mean())
driver_ontime=driver_ontime.sort_values(ascending=False)
print(driver_ontime)
# Out:
# driver_id
# DRV00120    0.507667
# DRV00036    0.490417
# DRV00113    0.488056
# DRV00100    0.482861
# DRV00020    0.482528
#               ...
# DRV00095    0.413611
# DRV00098    0.406639
# DRV00118    0.397361
# DRV00074    0.392361
# DRV00133    0.365194
# Name: on_time_delivery_rate, Length: 124, dtype: float64

# %%
top_10_drivers = driver_ontime.head(10)

print(top_10_drivers)
# Out:
# driver_id
# DRV00120    0.507667
# DRV00036    0.490417
# DRV00113    0.488056
# DRV00100    0.482861
# DRV00020    0.482528
# DRV00022    0.481167
# DRV00060    0.479111
# DRV00112    0.478917
# DRV00104    0.477750
# DRV00108    0.477167
# Name: on_time_delivery_rate, dtype: float64

# %%
plt.figure(figsize=(10, 5))

sns.barplot(
    x=top_10_drivers.index,
    y=top_10_drivers.values * 100,                                                                                                                                                                                               #* 100 poduradhu decimal value-a percentage value-aa convert panna.
    palette=["blue", "orange", "green", "red", "purple","brown", "pink", "gray", "olive", "cyan"])

for i, value in enumerate(top_10_drivers.values * 100):
    plt.text(                                                                                                                                                                                                                    #  #plt.text() na chart-la oru text/label-a particular position-la place panna use pannuvom.
        i,                                                                                                              #entha bar
        value,                                                                                                          #bar ku vara values
        f"{value:.2f}%",                                                                                                #values text la irukum
        ha="center"                                            
    )

plt.title("Top 10 Drivers by On-Time Delivery Rate", )
plt.xlabel("Driver ID", )
plt.ylabel("On-Time Delivery Rate (%)", )
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MOHAMEDSHAFITH\AppData\Local\Temp\ipykernel_22400\3772989951.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
trips
# Out:
#             trip_id       load_id driver_id  truck_id trailer_id  \
# 0      TRIP00000001  LOAD00000001  DRV00117  TRK00035   TRL00167
# 1      TRIP00000002  LOAD00000002  DRV00141  TRK00108   TRL00082
# 2      TRIP00000003  LOAD00000003  DRV00032  TRK00031   TRL00138
# 3      TRIP00000004  LOAD00000004  DRV00083  TRK00105   TRL00018
# 4      TRIP00000005  LOAD00000005  DRV00044  TRK00076   TRL00054
# ...             ...           ...       ...       ...        ...
# 85405  TRIP00085406  LOAD00085406  DRV00005  TRK00029   TRL00058
# 85406  TRIP00085407  LOAD00085407  DRV00091  TRK00080   TRL00092
# 85407  TRIP00085408  LOAD00085408  DRV00011  TRK00051   TRL00083
# 85408  TRIP00085409  LOAD00085409  DRV00094  TRK00073   TRL00137
# 85409  TRIP00085410  LOAD00085410  DRV00049  TRK00099   TRL00033
#
#       dispatch_date  actual_distance_miles  actual_duration_hours  \
# 0        2022-01-01                   1314                   26.2
# ...

# %%
maintenance_records
# Out:
#      maintenance_id  truck_id maintenance_date maintenance_type  \
# 0     MAINT00000001  TRK00085       2022-01-01       Inspection
# 1     MAINT00000002  TRK00041       2022-01-01             Tire
# 2     MAINT00000003  TRK00090       2022-01-01       Preventive
# 3     MAINT00000004  TRK00056       2022-01-02       Inspection
# 4     MAINT00000005  TRK00029       2022-01-02           Repair
# ...             ...       ...              ...              ...
# 2915  MAINT00002916  TRK00073       2024-12-30       Inspection
# 2916  MAINT00002917  TRK00044       2024-12-31       Preventive
# 2917  MAINT00002918  TRK00066       2024-12-31           Repair
# 2918  MAINT00002919  TRK00093       2024-12-31           Engine
# 2919  MAINT00002920  TRK00086       2024-12-31             Tire
#
#       odometer_reading  labor_hours  labor_cost  parts_cost  total_cost  \
# 0               400255          7.8      781.42       10.41      791.83
# ...

# %%
#maintenance_records
maintenance_records.info()
maintenance_records["year"] = pd.to_datetime(maintenance_records["maintenance_date"]).dt.year

maintenance_records["month_number"] = pd.to_datetime( maintenance_records["maintenance_date"]).dt.month
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2920 entries, 0 to 2919
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   maintenance_id       2920 non-null   object
#  1   truck_id             2920 non-null   object
#  2   maintenance_date     2920 non-null   datetime64[ns]
#  3   maintenance_type     2920 non-null   object
#  4   odometer_reading     2920 non-null   int64
#  5   labor_hours          2920 non-null   float64
#  6   labor_cost           2920 non-null   float64
#  7   parts_cost           2920 non-null   float64
#  8   total_cost           2920 non-null   float64
#  9   facility_location    2920 non-null   object
#  10  downtime_hours       2920 non-null   float64
#  11  service_description  2920 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(5)
# memory usage: 273.9+ KB

# %%
monthly_downtime = maintenance_records.groupby(
    ["year", "month_number"]
)["downtime_hours"].sum().unstack()
print(monthly_downtime)
# Out:
# month_number      1       2       3       4       5       6       7       8   \
# year
# 2022          1968.7  1631.9  1664.0  2590.4  1911.6  1717.4  2259.6  1796.7
# 2023          1987.7  1577.1  2466.7  2139.0  2325.3  1890.8  2021.4  2133.3
# 2024          2150.9  1556.3  2025.3  1837.2  1556.5  2434.2  1794.8  1851.1
#
# month_number      9       10      11      12
# year
# 2022          2258.2  2360.0  1831.8  2141.5
# 2023          1773.4  2584.0  1984.8  1926.5
# 2024          1870.4  2397.9  1975.8  1838.3

# %%
plt.figure(figsize=(12, 4))
sns.heatmap(
    monthly_downtime,
    annot=True,                                                                                                                                                                                                                   # cell-kulla value show pannu
    fmt=".0f")                                                                                                                                                                                                                    # decimal remove panni whole number show pannu
plt.title("Monthly Truck Downtime", fontsize=16)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Year", fontsize=12)
plt.tight_layout()
plt.show()

# %%
#Load revenue

load_revenue = loads[[
    "revenue",
    "fuel_surcharge",
    "accessorial_charges"
]]

print(load_revenue)
# Out:
#        revenue  fuel_surcharge  accessorial_charges
# 0      3045.23          406.72                  100
# 1      1224.48           98.61                    0
# 2      7171.12          792.88                    0
# 3      1308.20          141.33                   50
# 4      3317.18          738.48                    0
# ...        ...             ...                  ...
# 85405  2073.08          344.52                    0
# 85406  2018.31          114.30                    0
# 85407  3952.46          309.24                  200
# 85408  6296.47          463.93                   75
# 85409  4350.65          504.32                   75
#
# [85410 rows x 3 columns]

# %%
total_revenue = load_revenue["revenue"].sum()
total_fuel_surcharge = load_revenue["fuel_surcharge"].sum()
total_accessorial = load_revenue["accessorial_charges"].sum()

print(total_revenue)
print(total_fuel_surcharge)
print(total_accessorial)
# Out:
# 262525800.29
# 29976528.65
# 6119100

# %%
revenue_breakdown = pd.Series({                                                                                                                                                                                                    #pd.Series() use pannadhu andha 3 values-ku names attach panni. na Pandas-la one-dimensional data structure create panna use pannuvom.
    "Base Revenue": total_revenue,
    "Fuel Surcharge": total_fuel_surcharge,
    "Accessorial Charges": total_accessorial})

print(revenue_breakdown)                                                                                                                                                                                                           # output la scientific notation vanda reason --pd.Series() create pannumbodhu Pandas values-a float64 type-la store pannudhu.
# Out:
# Base Revenue           2.625258e+08
# Fuel Surcharge         2.997653e+07
# Accessorial Charges    6.119100e+06
# dtype: float64

# %%
waterfall_values = [                                                                                            #knjm clear ra puriyanum munnadiya eluti vachiruka namma chart laiya podalam knjm convient kaga potom
     total_revenue,
    total_fuel_surcharge,
    total_accessorial,
    total_revenue + total_fuel_surcharge + total_accessorial]

waterfall_labels = ["Base Revenue","Fuel Surcharge","Accessorial Charges","Total Revenue"]

print(waterfall_values)
# Out:
# [np.float64(262525800.29), np.float64(29976528.65), np.int64(6119100), np.float64(298621428.94)]

# %%
plt.figure(figsize=(10, 6))

bottom = [
    0,                                                                                                                        # 0 → first bar zero-lendhu start aaganum
    total_revenue,                                                                                                            #total_revenue → first bar (Base Revenue) mudinja place-lendhu second bar start aaganum
    total_revenue + total_fuel_surcharge,                                                                                     #total_revenue + total_fuel_surcharge → first 2 bars mudinja place-lendhu third bar start aaganum
    0                                                                                                                         #0 → last Total Revenue bar again zero-lendhu separate-aa start aaganum
]
plt.bar(
    waterfall_labels,
    waterfall_values,
    bottom=bottom,
    color=["blue", "orange", "green", "red"]
)

plt.title("Load Revenue Breakdown", fontsize=16)
plt.xlabel("Revenue Component", fontsize=12)
plt.ylabel("Revenue", fontsize=12)

plt.tight_layout()
plt.show()

# %%
customer_loads
# Out:
#             load_id customer_id  route_id  load_date     load_type  \
# 0      LOAD00000001   CUST00183  RTE00019 2022-01-01       Dry Van
# 1      LOAD00000002   CUST00076  RTE00058 2022-01-01       Dry Van
# 2      LOAD00000003   CUST00027  RTE00048 2022-01-01  Refrigerated
# 3      LOAD00000004   CUST00088  RTE00013 2022-01-01  Refrigerated
# 4      LOAD00000005   CUST00185  RTE00020 2022-01-01       Dry Van
# ...             ...         ...       ...        ...           ...
# 85405  LOAD00085406   CUST00016  RTE00039 2024-12-31  Refrigerated
# 85406  LOAD00085407   CUST00179  RTE00008 2024-12-31       Dry Van
# 85407  LOAD00085408   CUST00136  RTE00056 2024-12-31  Refrigerated
# 85408  LOAD00085409   CUST00012  RTE00016 2024-12-31  Refrigerated
# 85409  LOAD00085410   CUST00169  RTE00007 2024-12-31       Dry Van
#
#        weight_lbs  pieces  revenue  fuel_surcharge  accessorial_charges  \
# 0           19178      13  3045.23          406.72                  100
# ...

# %%
# second canvas -chart-2
load_type_weight = route_loads.groupby("load_type")["weight_lbs"].sum()                 #business motive==Different load types-la company evlo total cargo weight handle pannudhu-nu compare panni, endha load type-ku adhiga capacity/demand irukku-nu identify panna.

print(load_type_weight)
# Out:
# load_type
# Dry Van         1167640959
# Refrigerated    1179211915
# Name: weight_lbs, dtype: int64

# %%
load_type_weight = route_loads.groupby("load_type")["weight_lbs"].sum()                 #business motive==Different load types-la company evlo total cargo weight handle pannudhu-nu compare panni, endha load type-ku adhiga capacity/demand irukku-nu identify panna.

print(load_type_weight)

plt.figure(figsize=(8, 5))

sns.barplot(
    x=load_type_weight.index,
    y=load_type_weight.values
)

for i, value in enumerate(load_type_weight.values):
    plt.text(i, value, str(value), ha="center")

plt.title("Total Weight by Load Type", fontsize=16)
plt.xlabel("Load Type", fontsize=12)
plt.ylabel("Total Weight (lbs)", fontsize=12)

plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# load_type
# Dry Van         1167640959
# Refrigerated    1179211915
# Name: weight_lbs, dtype: int64

# %%
#“Different truck makes-oda average fuel tank capacity-a compare panni, endha truck make higher fuel capacity provide pannudhu-nu identify panradhu.”
truck_make_capacity = (
    trucks.groupby("make")["tank_capacity_gallons"] .mean().sort_values(ascending=True))

plt.figure(figsize=(10, 6))
sns.barplot(
    x=truck_make_capacity.values,
    y=truck_make_capacity.index,
    palette="Set2"                                                                                  #palette-Seaborn-oda predefined color collection
)
plt.title("Truck Make vs Average Tank Capacity", fontsize=16)
plt.xlabel("Average Tank Capacity (Gallons)", fontsize=12)
plt.ylabel("Truck Make", fontsize=12)

for i, value in enumerate(truck_make_capacity.values):
    plt.text(value, i, f"{value:.1f}", ha="center")


plt.grid(axis="x", linestyle="--", alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MOHAMEDSHAFITH\AppData\Local\Temp\ipykernel_22400\3433301048.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# “Different facility types-la ethana dock doors irukku ,edu highest check panna porom
plt.figure(figsize=(11, 6))

sns.boxplot(
    x=facilities["facility_type"],
    y=facilities["dock_doors"],
    palette="Set2")

plt.title("Facility Type vs Dock Doors",fontsize=16)
plt.xlabel("Facility Type", fontsize=12)
plt.ylabel("Number of Dock Doors", fontsize=12)
plt.grid(  axis="y", linestyle="--",alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MOHAMEDSHAFITH\AppData\Local\Temp\ipykernel_22400\1092525929.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
# Different trailer types-la trailers-oda model year distribution-a compare panni, endha trailer type newer/older irukku-nu identify panrom.
plt.figure(figsize=(10, 6))


sns.violinplot(
    x=trailers["trailer_type"],
    y=trailers["model_year"],
    palette="Set2",
    inner="quartile"
)

# Chart title
plt.title(
    "Trailer Type vs Model Year Distribution",
    fontsize=16
)
plt.xlabel("Trailer Type", fontsize=12)
plt.ylabel("Model Year", fontsize=12)
plt.grid(
    axis="y",
    linestyle="--",
    alpha=0.4
)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MOHAMEDSHAFITH\AppData\Local\Temp\ipykernel_22400\2705519936.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %%
# Motive: Route distance increase aagumbodhu base rate per mile eppadi change aagudhu-nu identify panna, route pricing-a better-ah understand panna.

plt.figure(figsize=(10, 6))

sns.scatterplot(
    x="typical_distance_miles",
    y="base_rate_per_mile",
    data=routes,                                                                      #dataframe
    s=80,                                                                            #Ovvoru dot-oda size set panradhu.
    color="#4C78A8",
    edgecolor="black",
    alpha=0.75)

plt.title(
    "Route Distance vs Base Rate per Mile",
    fontsize=16,
    fontweight="bold")

plt.xlabel("Typical Distance (Miles)",fontsize=12
)
plt.ylabel("Base Rate per Mile",fontsize=12
)
plt.grid(linestyle="--",alpha=0.25)
sns.despine()
plt.tight_layout()
plt.show()

# %%
#“Customer account status based on average annual revenue potential-a compare panni, endha customer status-la higher business opportunity irukku-nu identify panna.”

account_revenue = (customers.groupby("account_status")["annual_revenue_potential"].mean().sort_values(ascending=False))

plt.figure(figsize=(10, 6))

sns.pointplot(
    x=account_revenue.index,
    y=account_revenue.values,
    color="#4C78A8",                                                       #color-oda HEX code
    markers="o",
    linestyles="-")

for i, value in enumerate(account_revenue.values):
    plt.text(i,value + 5000,f"${value:,.0f}",ha="center",fontsize=10,fontweight="bold")

plt.title(    "Customer Account Status vs Average Revenue Potential",fontsize=16,fontweight="bold")
plt.xlabel("Account Status", fontsize=12)
plt.ylabel("Average Annual Revenue Potential", fontsize=12)
plt.grid(axis="y",linestyle="--",alpha=0.3)
plt.tight_layout()
plt.show()

# %%
#Different locations-la trailer length same-ah irukka illa different-ah irukka-nu check panna.

#Endha location-la enna size trailer irukku-nu compare panni, trailer allocation and capacity planning-ku use panna.

plt.figure(figsize=(26, 9))

sns.stripplot(
    data=trailers,
    x="current_location",
    y="length_feet",
    hue="current_location",
    palette="Set2",
    jitter=0.25,                                         #overlap aagama individual dots visible-ah irukka.
    size=6,
    alpha=0.7,
    legend=False)

plt.title("Trailer Length Across Current Locations",fontsize=16,fontweight="bold")
plt.xlabel("Current Location", fontsize=12)
plt.ylabel("Trailer Length (Feet)", fontsize=12)
plt.grid(
    axis="y",
    linestyle="--",
    alpha=0.3)
sns.despine()
plt.tight_layout()
plt.show()

# %%
drivers
# Out:
#     driver_id first_name  last_name   hire_date termination_date  \
# 0    DRV00001   Jennifer  Hernandez  2014-10-31              NaN
# 1    DRV00002    William     Martin  2020-10-02              NaN
# 2    DRV00003    Charles  Hernandez  2021-09-21              NaN
# 3    DRV00004    Barbara      Brown  2013-09-08              NaN
# 4    DRV00005       Mary   Martinez  2018-12-02              NaN
# ..        ...        ...        ...         ...              ...
# 145  DRV00146    Jessica   Gonzalez  2019-01-13              NaN
# 146  DRV00147    Richard     Garcia  2020-06-09              NaN
# 147  DRV00148   Patricia   Anderson  2019-03-28              NaN
# 148  DRV00149      Linda      Jones  2013-08-25              NaN
# 149  DRV00150     Robert     Martin  2015-09-16              NaN
#
#     license_number license_state date_of_birth   home_terminal  \
# 0      DL673510887            WA    1973-11-07          Denver
# ...

# %%
# “Different CDL classes-la irukkura drivers-la, yaar Active / Inactive nu compare panni, driver workforce and staffing requirements-a better-ah plan panna.

driver_status = (
    drivers.groupby(["cdl_class", "employment_status"])
    .size().unstack())                                                  #list maari irukura values table format-ku convert pannum.

plt.figure(figsize=(10, 6))

sns.heatmap(
    driver_status,
    annot=True,
    fmt="d",                           #integer / decimal illaadha number format la katum   
    cmap="YlGnBu",
    linewidths=0.8
)

plt.title("Driver CDL Class vs Employment Status",fontsize=16,fontweight="bold")
plt.xlabel("Employment Status", fontsize=12)
plt.ylabel("CDL Class", fontsize=12)
plt.tight_layout()
plt.show()

# %%
# “Different facility types-la irukkura dock door capacity-a compare panni, endha facility type-la loading/unloading capacity adhigama irukku-nu identify panna.

plt.figure(figsize=(11, 6))

sns.swarmplot(
    data=facilities,
    x="facility_type",
    y="dock_doors",
    hue="facility_type",
    size=7,
    legend=False)

plt.title("Facility Type vs Dock Door Capacity",fontsize=16,fontweight="bold")
plt.xlabel("Facility Type", fontsize=12)
plt.ylabel("Number of Dock Doors", fontsize=12)
plt.grid(axis="y",linestyle="--",alpha=0.3)
sns.despine()
plt.tight_layout()
plt.show()

# %%
print(terminal_experience)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 print(terminal_experience)
#
# NameError: name 'terminal_experience' is not defined

# %%
# Endha terminal-la experienced drivers adhigama irukkanga-nu kandupidichu, driver allocation and workforce planning-a better-ah panna.

terminal_experience = (
    drivers.groupby("home_terminal")["years_experience"]
    .mean()
    .sort_values()
)

plt.figure(figsize=(11, 6))

# Lollipop chart
plt.vlines(
    x=range(len(terminal_experience)),                                            #len() → "Ethana irukku?" nu count pannum.
    ymin=0,                                                                      #range() → "Andha count-ku positions kudu" nu numbers create pannum.
    ymax=terminal_experience.values,                                                #ymax na vertical line enga varaikkum poganum nu solludhu.
    linewidth=2
)

plt.scatter(
    range(len(terminal_experience)),
    terminal_experience.values,
    s=100)

plt.xticks(
    range(len(terminal_experience)),
    terminal_experience.index,
    rotation=45
)
plt.title("Average Driver Experience by Home Terminal",fontsize=16,fontweight="bold")
plt.xlabel("Home Terminal", fontsize=12)
plt.ylabel("Average Years of Experience", fontsize=12)
plt.grid(axis="y",linestyle="--",alpha=0.3)
sns.despine()   
plt.tight_layout()
plt.show()

# %%
# Facilities enga enga located-a irukku-nu paathu, company-oda logistics network geographic-ah eppadi spread aagirukku-nu understand panna.

plt.figure(figsize=(11, 7))

# Each point = one facility
sns.scatterplot(
    data=facilities,
    x="longitude",
    y="latitude",
    hue="facility_type",
    s=120,
    alpha=0.8
)

# Chart title
plt.title("Logistics Facility Geographic Distribution", fontsize=16,fontweight="bold")
plt.xlabel("Longitude", fontsize=12)
plt.ylabel("Latitude", fontsize=12)
plt.grid(linestyle="--",alpha=0.25)
plt.legend(
    title="Facility Type",
    bbox_to_anchor=(1.02, 1),                                                            #1.02 → chart-oda right side-ku konjam outside #1 → chart-oda top position
    loc="upper left"
)
sns.despine()
plt.tight_layout()
plt.show()

# %%
# truck vangumbodu  pannumbodhu, andha truck already evlo miles odirukku nu paakurom

plt.figure(figsize=(10, 6))

sns.histplot(
    data=trucks,
    x="acquisition_mileage",
    hue="fuel_type",
    bins=15,
    kde=True
)

plt.title("Acquisition Mileage Distribution by Fuel Type")
plt.xlabel("Acquisition Mileage")
plt.ylabel("Number of Trucks")

plt.tight_layout()
plt.show()

# %%
load_type_weight = route_loads.groupby("load_type")["weight_lbs"].sum()                 #business motive==Different load types-la company evlo total cargo weight handle pannudhu-nu compare panni, endha load type-ku adhiga capacity/demand irukku-nu identify panna.

print(load_type_weight)

plt.figure(figsize=(8, 5))

sns.barplot(
    x=load_type_weight.index,
    y=load_type_weight.values
)

for i, value in enumerate(load_type_weight.values):
    plt.text(i, value, str(value), ha="center")

plt.title("Total Weight by Load Type", fontsize=16)
plt.xlabel("Load Type", fontsize=12)
plt.ylabel("Total Weight (lbs)", fontsize=12)

plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# load_type
# Dry Van         1167640959
# Refrigerated    1179211915
# Name: weight_lbs, dtype: int64

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# 1. Truck Make vs Average Tank Capacity

truck_make_capacity = (
    trucks.groupby("make")["tank_capacity_gallons"]
    .mean()
    .sort_values(ascending=True)
)

sns.barplot(
    x=truck_make_capacity.values,
    y=truck_make_capacity.index,
    palette="Set2",
    ax=axes[0, 0]
)

axes[0, 0].set_title(
    "Truck Make vs Average Tank Capacity",
    fontsize=16
)
axes[0, 0].set_xlabel(
    "Average Tank Capacity (Gallons)",
    fontsize=12
)
axes[0, 0].set_ylabel(
    "Truck Make",
    fontsize=12
)

for i, value in enumerate(truck_make_capacity.values):
    axes[0, 0].text(
        value,
        i,
        f"{value:.1f}",
        ha="center"
    )

axes[0, 0].grid(
    axis="x",
    linestyle="--",
    alpha=0.4
)


# 2. Facility Type vs Dock Doors

sns.boxplot(
    x=facilities["facility_type"],
    y=facilities["dock_doors"],
    palette="Set2",
    ax=axes[0, 1]
)

axes[0, 1].set_title(
    "Facility Type vs Dock Doors",
    fontsize=16
)
axes[0, 1].set_xlabel(
    "Facility Type",
    fontsize=12
)
axes[0, 1].set_ylabel(
    "Number of Dock Doors",
    fontsize=12
)

axes[0, 1].grid(
    axis="y",
    linestyle="--",
    alpha=0.4
)


# 3. Trailer Type vs Model Year Distribution

sns.violinplot(
    x=trailers["trailer_type"],
    y=trailers["model_year"],
    palette="Set2",
    inner="quartile",
    ax=axes[1, 0]
)

axes[1, 0].set_title(
    "Trailer Type vs Model Year Distribution",
    fontsize=16
)
axes[1, 0].set_xlabel(
    "Trailer Type",
    fontsize=12
)
axes[1, 0].set_ylabel(
    "Model Year",
    fontsize=12
)

axes[1, 0].grid(
    axis="y",
    linestyle="--",
    alpha=0.4
)


# 4. Route Distance vs Base Rate per Mile

sns.scatterplot(
    x="typical_distance_miles",
    y="base_rate_per_mile",
    data=routes,
    s=80,
    color="#4C78A8",
    edgecolor="black",
    alpha=0.75,
    ax=axes[1, 1]
)

axes[1, 1].set_title(
    "Route Distance vs Base Rate per Mile",
    fontsize=16,
    fontweight="bold"
)
axes[1, 1].set_xlabel(
    "Typical Distance (Miles)",
    fontsize=12
)
axes[1, 1].set_ylabel(
    "Base Rate per Mile",
    fontsize=12
)

axes[1, 1].grid(
    linestyle="--",
    alpha=0.25
)


plt.tight_layout()
plt.show()
# Out:
# C:\Users\MOHAMEDSHAFITH\AppData\Local\Temp\ipykernel_27340\2031987049.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\MOHAMEDSHAFITH\AppData\Local\Temp\ipykernel_27340\2031987049.py:49: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\MOHAMEDSHAFITH\AppData\Local\Temp\ipykernel_27340\2031987049.py:78: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 10))


# 1. Total Weight by Load Type

load_type_weight = (
    route_loads.groupby("load_type")["weight_lbs"]
    .sum()
)

sns.barplot(
    x=load_type_weight.index,
    y=load_type_weight.values,
    ax=axes[0, 0]
)

for i, value in enumerate(load_type_weight.values):
    axes[0, 0].text(
        i,
        value,
        str(value),
        ha="center"
    )

axes[0, 0].set_title(
    "Total Weight by Load Type",
    fontsize=16
)
axes[0, 0].set_xlabel(
    "Load Type",
    fontsize=12
)
axes[0, 0].set_ylabel(
    "Total Weight (lbs)",
    fontsize=12
)

axes[0, 0].grid(
    axis="y",
    linestyle="--",
    alpha=0.5
)


# 2. Customer Account Status vs Average Revenue Potential

account_revenue = (
    customers.groupby("account_status")["annual_revenue_potential"]
    .mean()
    .sort_values(ascending=False)
)

sns.pointplot(
    x=account_revenue.index,
    y=account_revenue.values,
    color="#4C78A8",
    markers="o",
    linestyles="-",
    ax=axes[0, 1]
)

for i, value in enumerate(account_revenue.values):
    axes[0, 1].text(
        i,
        value + 5000,
        f"${value:,.0f}",
        ha="center",
        fontsize=10,
        fontweight="bold"
    )

axes[0, 1].set_title(
    "Customer Account Status vs Average Revenue Potential",
    fontsize=16,
    fontweight="bold"
)
axes[0, 1].set_xlabel(
    "Account Status",
    fontsize=12
)
axes[0, 1].set_ylabel(
    "Average Annual Revenue Potential",
    fontsize=12
)

axes[0, 1].grid(
    axis="y",
    linestyle="--",
    alpha=0.3
)


# 3. Trailer Length Across Current Locations

sns.stripplot(
    data=trailers,
    x="current_location",
    y="length_feet",
    hue="current_location",
    palette="Set2",
    jitter=0.25,
    size=6,
    alpha=0.7,
    legend=False,
    ax=axes[1, 0]
)

axes[1, 0].set_title(
    "Trailer Length Across Current Locations",
    fontsize=16,
    fontweight="bold"
)
axes[1, 0].set_xlabel(
    "Current Location",
    fontsize=12
)
axes[1, 0].set_ylabel(
    "Trailer Length (Feet)",
    fontsize=12
)

axes[1, 0].tick_params(
    axis="x",
    rotation=45
)

axes[1, 0].grid(
    axis="y",
    linestyle="--",
    alpha=0.3
)


# 4. Driver CDL Class vs Employment Status

driver_status = (
    drivers.groupby(
        ["cdl_class", "employment_status"]
    )
    .size()
    .unstack()
)

sns.heatmap(
    driver_status,
    annot=True,
    fmt="d",
    cmap="YlGnBu",
    linewidths=0.8,
    ax=axes[1, 1]
)

axes[1, 1].set_title(
    "Driver CDL Class vs Employment Status",
    fontsize=16,
    fontweight="bold"
)
axes[1, 1].set_xlabel(
    "Employment Status",
    fontsize=12
)
axes[1, 1].set_ylabel(
    "CDL Class",
    fontsize=12
)


plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 10))


# 1. Facility Type vs Dock Door Capacity

sns.swarmplot(
    data=facilities,
    x="facility_type",
    y="dock_doors",
    hue="facility_type",
    size=7,
    legend=False,
    ax=axes[0, 0]
)

axes[0, 0].set_title(
    "Facility Type vs Dock Door Capacity",
    fontsize=16,
    fontweight="bold"
)
axes[0, 0].set_xlabel(
    "Facility Type",
    fontsize=12
)
axes[0, 0].set_ylabel(
    "Number of Dock Doors",
    fontsize=12
)

axes[0, 0].grid(
    axis="y",
    linestyle="--",
    alpha=0.3
)


# 2. Average Driver Experience by Home Terminal

terminal_experience = (
    drivers.groupby("home_terminal")["years_experience"]
    .mean()
    .sort_values()
)

axes[0, 1].vlines(
    x=range(len(terminal_experience)),
    ymin=0,
    ymax=terminal_experience.values,
    linewidth=2
)

axes[0, 1].scatter(
    range(len(terminal_experience)),
    terminal_experience.values,
    s=100
)

axes[0, 1].set_xticks(
    range(len(terminal_experience))
)

axes[0, 1].set_xticklabels(
    terminal_experience.index,
    rotation=45
)

axes[0, 1].set_title(
    "Average Driver Experience by Home Terminal",
    fontsize=16,
    fontweight="bold"
)
axes[0, 1].set_xlabel(
    "Home Terminal",
    fontsize=12
)
axes[0, 1].set_ylabel(
    "Average Years of Experience",
    fontsize=12
)

axes[0, 1].grid(
    axis="y",
    linestyle="--",
    alpha=0.3
)


# 3. Logistics Facility Geographic Distribution

sns.scatterplot(
    data=facilities,
    x="longitude",
    y="latitude",
    hue="facility_type",
    s=120,
    alpha=0.8,
    ax=axes[1, 0]
)

axes[1, 0].set_title(
    "Logistics Facility Geographic Distribution",
    fontsize=16,
    fontweight="bold"
)
axes[1, 0].set_xlabel(
    "Longitude",
    fontsize=12
)
axes[1, 0].set_ylabel(
    "Latitude",
    fontsize=12
)

axes[1, 0].grid(
    linestyle="--",
    alpha=0.25
)

axes[1, 0].legend(
    title="Facility Type",
    bbox_to_anchor=(1.02, 1),
    loc="upper left"
)


# 4. Acquisition Mileage Distribution by Fuel Type

sns.histplot(
    data=trucks,
    x="acquisition_mileage",
    hue="fuel_type",
    bins=15,
    kde=True,
    ax=axes[1, 1]
)

axes[1, 1].set_title(
    "Acquisition Mileage Distribution by Fuel Type",
    fontsize=16
)
axes[1, 1].set_xlabel(
    "Acquisition Mileage",
    fontsize=12
)
axes[1, 1].set_ylabel(
    "Number of Trucks",
    fontsize=12
)


plt.tight_layout()
plt.show()
